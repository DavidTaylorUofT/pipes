# %% [markdown]
# <p> manually set node 6-9 as full opening </p>
# <p> change dt from 0.015s to 0.01s (less than 0.015s, 0.012s also works,try now), which always works</p>
# <p> Courant Number = 0.54 for dt=0.012s, =0.675 for dt=0.015s, more than 0.675 does not work</p>
# <p> Increase inflow means decreasing dt </p>

# %%
import sys
sys.path.append("..")    
from allthethings import PyNetwork, PyPipe_ps
from allthethings import PyBC_opt_dh
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
from writeit import *
import pickle
import time
#from __future__ import division
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fi = "../indata/Model2/Model2_Epipe_new.inp"    
fc = "../indata/Model2/Model2_Epipe_new.config" 
mtype=1
n1=PyNetwork(fi,fc,mtype)

# %%
'''
(xs,ys,conns,ls) = getBasicConnectivity(fi)
Np= shape(conns) [0]
plotNetworkLayout (xs, ys, conns, ls, Np) 
n1.showLayout() 
'''
# Out:
# '\n(xs,ys,conns,ls) = getBasicConnectivity(fi)\nNp= shape(conns) [0]\nplotNetworkLayout (xs, ys, conns, ls, Np) \nn1.showLayout() \n'

# %%
v = 2
Q_in = n1.Ds[0]**2*pi/4*v
n1.setbVal(0,Q_in*np.ones(n1.M+1))
jt = n1.nodeTypes
n1.setbVal(5,n1.Ds[4]*np.ones(n1.M+1))
dt = n1.T/n1.M  
print dt
# Out:
# 0.012

# %%
V0 = n1.getTotalVolume()                 
n1.runForwardProblem(dt) 
V1= n1.getTotalVolume()
print "The total run time is %f s, the total volume change is %f %f cubic meters" %(n1.solve_time, V1,V0)
# Out:
# The total run time is 145.263141 s, the total volume change is 44.092052 0.019358 cubic meters

# %%
# Pressure Head of Pipe_interest changes with time, dynamic picture
# %matplotlib notebook
#%matplotlib nbagg
import pylab as pl
from IPython import display
plt.ion()
plt.show()

pipe_interest=[0,1,2,3,4]

# create x axis
x_interest=[]
pipe_length=0
for j in pipe_interest: 
    x = np.linspace(pipe_length,pipe_length+n1.Ls[j],n1.Ns[j])
    x_interest.append(x)
    pipe_length=pipe_length+n1.Ls[j]

# create H_interest which stores all the pressure head data corresponding to x

# H_interest_tfixed = [Hx1,Hx2,...,Hxj], pressure head at a certain time along all interesting pipes

# H_interested =n [H_interested1, H_interested2,..., H_interestedT], H_interested[i] =  fixed time step at i*Mi_draw
# dthen get ata from H_interested_tfixed

H_interest=[]
Mi_draw=1000   # difne how many steps to skip
M_total=n1.M+1
x_interest_combine = np.concatenate(x_interest,axis =0)
for m in range(0,M_total,Mi_draw) :  
    H_interest_tfixed=[]
    for j in pipe_interest:    
        Hx = n1.pressureSpaceSeries(j,m)  
        #this returns H as a function of x in pipe j at time step m
        H_interest_tfixed.append(Hx)
    H_interest.append(H_interest_tfixed)
    #plt.figure(figsize= (15,5))    #plot on different figures
    H_interest_combine = np.concatenate(H_interest[int(m/Mi_draw)],axis =0)
    pl.clf()
    figsize= (15,5)               #plot on the same figure
    pl.plot(x_interest_combine,H_interest_combine, lw = 1,label = 't=%.2f s'%(dt*m))
    # m is time step, and should divide m/Mi_draw to get what we need
    xlabel('x (m)')        
    ylabel('Pressure Head (m)')
    xlim(0,x_interest[-1][-1]+1)
    Hmax=max(H_interest_combine)
    #ylim(-0.1,12)
    ylim(-0.1,1.1*Hmax)
    legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    title('Pressure Head along pipe %s'%str(pipe_interest)) 
    display.display(pl.gcf())
    display.clear_output(wait=True)
    #time.sleep(0.01)
    # bbox_to_anchor: the bbox that the legend will be anchored, 1.05 means 1.05 times of figure length
    # borderaxespad: the pad between the axes and legend border
    # optional:legend(loc = 'upper left')

# %%
A_pipe=[]
for i in range(len(pipe_interest)):
    pipe_number=pipe_interest[i]
    A_pipe.append(n1.Ds[pipe_number]**2/4*pi)
    print 'pipe %d cross sectional area: A=%.4f m^2'%(pipe_number,A_pipe[i])
# Out:
# pipe 0 cross sectional area: A=0.0707 m^2
# pipe 1 cross sectional area: A=0.0707 m^2
# pipe 2 cross sectional area: A=0.0707 m^2
# pipe 3 cross sectional area: A=0.0707 m^2
# pipe 4 cross sectional area: A=0.0707 m^2

# %%
# the veolcity in pipe_interest changes with time ,dynamic picture
U_interest=[]
def idx_t(i,j,n,N):
    return (2*(N+2)*n+(N+2)*i+j)
#M_total=Mi_draw*1+1
Mi_draw=3000
for m in range(0,M_total,Mi_draw) :
    U_interest_tfixed=[] 
    for i in range(len(pipe_interest)):
        j = pipe_interest[i]
        N = n1.Ns[j]
        qh = n1.qhist(j) 
        Utemp=[]
        for k in range(1,N+1):
            Ak=qh[idx_t(0,k,m,N)]
            AN=qh[idx_t(0,N,m,N)]
            Qk=qh[idx_t(1,k,m,N)]
            # when Q is actually very samll and its value is due to numerical oscillation, set it as 0
            if abs(Ak-AN)<0.1*A_pipe[i] and AN<0.1*A_pipe[i]:  
                Qk=0   
            vk = Qk/Ak                 
            Utemp.append(vk)
            #Utemp=[qh[idx_t(1,k,m,N)]/qh[idx_t(0,k,m,N)] for k in range(1,N+1)]
        U_interest_tfixed.append(Utemp)
    U_interest.append(U_interest_tfixed)
    U_interest_combine = np.concatenate(U_interest[int(m/Mi_draw)],axis =0)
    # plt.figure(figsize= (15,5))    #plot on different figures
    figsize= (15,5)                 #plot on the same figure
    pl.clf()
    pl.plot(x_interest_combine,U_interest_combine, lw = 1,label = 't=%.2f s'%(dt*m))
    '''
    #plt.figure(figsize= (15,5))
    for i in range(len(pipe_interest)):
        figsize(15,5)
        plot(x_interest[i],U_interest[int(m/Mi_draw)][i], lw = 1,  label = 'pipe %d, t=%.2f s'%(pipe_interest[i],dt*m))
        # m is time step, and should divide m/Mi_draw to get what we need
        #plot(x,Hx, lw = 1, color = sMap.to_rgba(m), label = 't=%.2f'%(dt*m))
    '''
    xlabel('x (m)')        
    ylabel('Velocity (m/s)')
    xlim(0,x_interest[-1][-1]+1)
    Umax=1.1*max(U_interest_combine)
    #ylim(-0.1,2.5)
    ylim(-0.5,1.2*Umax)
    #print int(m/Mi_draw)      #for test
    legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    title('Velocity along pipe %s'%str(pipe_interest))
    display.display(pl.gcf())
    display.clear_output(wait=True)
    #time.sleep(0.01)
    # print U_interest[5][1]   # first index is #*Mi timestep, second index is pipe # in pipe_interest list

# %%
# Plot the Pressure head at the end of outflow pipes
t = linspace(0,n1.T,n1.M+1)
for i in xrange(1,len(jt)):
    if jt[i]==1:
        pipe_number=i-1
        Pend = n1.pressureTimeSeries(int(pipe_number),n1.Ns[pipe_number])
        Pstart=n1.pressureTimeSeries(int(pipe_number),1)
        #figsize=(15,5)
        #plt.figure(figsize= (10,4))
        #plt.plot(t,Pstart,label = "start of pipe %d" %(i-1))
        #legend()
        plt.figure(figsize= (10,4))                  # so that every time it can create a new figure
        plt.plot(t,Pend,label = "End of pipe %d" %(i-1))
        xlabel('t(s)')
        ylabel('H(m)')
        legend()
        title('Pressure Head at end of pipe %d'%pipe_number)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
"""
# Velocity of pipe_interest pipes, static image
U_interest=[]
def idx_t(i,j,n,N):
    return (2*(N+2)*n+(N+2)*i+j)

Mi_draw=10000
for m in range(0,M_total,Mi_draw) :
    U_interest_tfixed=[] 
    for i in range(len(pipe_interest)):
        j = pipe_interest[i]
        N = n1.Ns[j]
        qh = n1.qhist(j) 
        Utemp=[]
        for k in range(1,N+1):
            Ak=qh[idx_t(0,k,m,N)]
            AN=qh[idx_t(0,N,m,N)]
            Qk=qh[idx_t(1,k,m,N)]
            # when Q is actually very samll and its value is due to numerical oscillation, set it as 0
            if abs(Ak-AN)<0.1*A_pipe[i] and AN<0.1*A_pipe[i]:  
                Qk=0   
            vk = Qk/Ak                 
            Utemp.append(vk)
        U_interest_tfixed.append(Utemp)
    U_interest.append(U_interest_tfixed)
    U_interest_combine = np.concatenate(U_interest[int(m/Mi_draw)],axis =0)
    plt.figure(figsize= (10,4))    #plot on different figures
    #figsize= (15,5)                 #plot on the same figure
    plt.plot(x_interest_combine,U_interest_combine, lw = 1,label = 't=%.2f s'%(dt*m))
    '''
    #plt.figure(figsize= (15,5))
    for i in range(len(pipe_interest)):
        figsize(15,5)
        plot(x_interest[i],U_interest[int(m/Mi_draw)][i], lw = 1,  label = 'pipe %d, t=%.2f s'%(pipe_interest[i],dt*m))
        # m is time step, and should divide m/Mi_draw to get what we need
        #plot(x,Hx, lw = 1, color = sMap.to_rgba(m), label = 't=%.2f'%(dt*m))
    '''
    xlabel('x (m)')        
    ylabel('Velocity (m/s)')
    xlim(0,x_interest[-1][-1]+1)
    Umax=1.1*max(U_interest_combine)
    #ylim(-0.1,2.5)
    ylim(-0.1,1.2*Umax)
    #print int(m/Mi_draw)      #for test
    legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    title('Velocity along pipe %s'%str(pipe_interest))
    # print U_interest[5][1]   # first index is #*Mi timestep, second index is pipe # in pipe_interest list
"""
# Out:
# "\n# Velocity of pipe_interest pipes, static image\nU_interest=[]\ndef idx_t(i,j,n,N):\n    return (2*(N+2)*n+(N+2)*i+j)\n\nMi_draw=10000\nfor m in range(0,M_total,Mi_draw) :\n    U_interest_tfixed=[] \n    for i in range(len(pipe_interest)):\n        j = pipe_interest[i]\n        N = n1.Ns[j]\n        qh = n1.qhist(j) \n        Utemp=[]\n        for k in range(1,N+1):\n            Ak=qh[idx_t(0,k,m,N)]\n            AN=qh[idx_t(0,N,m,N)]\n            Qk=qh[idx_t(1,k,m,N)]\n            # when Q is actually very samll and its value is due to numerical oscillation, set it as 0\n            if abs(Ak-AN)<0.1*A_pipe[i] and AN<0.1*A_pipe[i]:  \n                Qk=0   \n            vk = Qk/Ak                 \n            Utemp.append(vk)\n        U_interest_tfixed.append(Utemp)\n    U_interest.append(U_interest_tfixed)\n    U_interest_combine = np.concatenate(U_interest[int(m/Mi_draw)],axis =0)\n    plt.figure(figsize= (10,4))    #plot on different figures\n    #figsize= (15,5)                 #plot on the same figure\n    plt.plot(x_interest_combine,U_interest_combine, lw = 1,label = 't=%.2f s'%(dt*m))\n    '''\n    #plt.figure(figsize= (15,5))\n    for i in range(len(pipe_interest)):\n        figsize(15,5)\n        plot(x_interest[i],U_interest[int(m/Mi_draw)][i], lw = 1,  label = 'pipe %d, t=%.2f s'%(pipe_interest[i],dt*m))\n        # m is time step, and should divide m/Mi_draw to get what we need\n        #plot(x,Hx, lw = 1, color = sMap.to_rgba(m), label = 't=%.2f'%(dt*m))\n    '''\n    xlabel('x (m)')        \n    ylabel('Velocity (m/s)')\n    xlim(0,x_interest[-1][-1]+1)\n    Umax=1.1*max(U_interest_combine)\n    #ylim(-0.1,2.5)\n    ylim(-0.1,1.2*Umax)\n    #print int(m/Mi_draw)      #for test\n    legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)\n    title('Velocity along pipe %s'%str(pipe_interest))\n    # print U_interest[5][1]   # first index is #*Mi timestep, second index is pipe # in pipe_interest list\n"

# %%
# Display the inflow and outflow for each pipe (m^3)
# Get Q of two ends of each pipe
Q = []
Mstep=1
#pipe_interest=[0]
pipe_interest=range(0,9)   
'''Here I redefine the pipe_interest vector'''

for i in range(len(pipe_interest)):
    Q_pipefix = [] 
    Q_start=[]
    Q_end=[]
    for m in xrange(0,n1.M,Mstep) :
        j = pipe_interest[i]
        N = n1.Ns[j]
        qh = n1.qhist(j)
        Q_start.append(qh[idx_t(1,1,m,N)])   # Q1
        Q_end.append(qh[idx_t(1,N,m,N)])     # QN
    Q_pipefix.append(Q_start)
    Q_pipefix.append(Q_end)
    Q.append(Q_pipefix)
xt = np.linspace(0, n1.M*dt, n1.M/Mstep)
endorstart=['start','end']
for i in range(len(pipe_interest)):
    plt.figure(figsize= (10,4))                # same pipe on same figure
    for j in range(0,2):  
        #figsize = (15,5)                        # plot on same figure           
        #plt.figure(figsize= (15,5))             # plot on different figures
        plot(xt,Q[i][j], lw = 1,label = 'pipe %d, %s'%(pipe_interest[i],endorstart[j]))
        #legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)   #legend will be placed out of box and cannot be shown
        legend()
        xlabel('time (s)')
        ylabel('flux (m^3/s)')
        title('Flux in pipe %d'%pipe_interest[i])

# calculate inflow and outflow, i means pipe number, j means start or end, time means time in vector  
delta_t=Mstep*dt
#Q_total=[]
for i in range(len(pipe_interest)):
    Q_total_pipefix=[]
    for j in range(0,2):
        Q_sum=0
        for time in range(len(Q[i][j])):
            Q_sum += Q[i][j][time]*delta_t
        Q_total_pipefix.append(Q_sum)
        print 'Pipe %d during %d s have total flow: %.3f m^3 (%s node)'%(pipe_interest[i],n1.T,Q_sum,endorstart[j])
    V_dif = Q_total_pipefix[0]- Q_total_pipefix[1]
    print V_dif
    #Q_total.append(Q_total_pipefix)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Pipe 0 during 1800 s have total flow: 254.131 m^3 (start node)
# Pipe 0 during 1800 s have total flow: 247.393 m^3 (end node)
# 6.73794149297
# Pipe 1 during 1800 s have total flow: 143.037 m^3 (start node)
# Pipe 1 during 1800 s have total flow: 132.398 m^3 (end node)
# 10.6386576032
# Pipe 2 during 1800 s have total flow: 80.972 m^3 (start node)
# Pipe 2 during 1800 s have total flow: 58.807 m^3 (end node)
# 22.1647014116
# Pipe 3 during 1800 s have total flow: 54.238 m^3 (start node)
# Pipe 3 during 1800 s have total flow: 24.935 m^3 (end node)
# 29.302903418
# Pipe 4 during 1800 s have total flow: 18.198 m^3 (start node)
# Pipe 4 during 1800 s have total flow: 7.152 m^3 (end node)
# 11.0461436809
# Pipe 5 during 1800 s have total flow: 136.803 m^3 (start node)
# Pipe 5 during 1800 s have total flow: 110.607 m^3 (end node)
# 26.1959055641
# Pipe 6 during 1800 s have total flow: 64.124 m^3 (start node)
# Pipe 6 during 1800 s have total flow: 59.164 m^3 (end node)
# 4.96075598899
# Pipe 7 during 1800 s have total flow: 28.719 m^3 (start node)
# Pipe 7 during 1800 s have total flow: 36.630 m^3 (end node)
# -7.91122588702
# Pipe 8 during 1800 s have total flow: 13.582 m^3 (start node)
# Pipe 8 during 1800 s have total flow: 19.228 m^3 (end node)
# -5.64603056272

# %%
# Display mass balance for each junction

# Create x axis
xt = np.linspace(0, n1.M*dt, n1.M/Mstep)

#The following three list must corresponds to each other  
JunNode=[1,2,3,4]
Pipejun_in=[[0],[1],[2],[3]]
Pipejun_out=[[1,5],[2,6],[3,7],[4,8]]
assert (len(Pipejun_in)==len(Pipejun_out)),"Different dimensions of Pipejun_in and Pipejun_out!"

# Q[i][j][k]   i means pipe number, j means start or end, k means time in vector 
for i in xrange(len(Pipejun_in)):
    Qjun_dif = []
    for k in xrange(len(Q[0][1])):
        Qinflow = 0
        Qoutflow = 0
        for j1 in Pipejun_in[i]:
            Qinflow += Q[j1][1][k]
        for j2 in Pipejun_out[i]:
            Qoutflow += Q[j2][0][k]
        Qjun_dif.append(Qinflow-Qoutflow)
    plt.figure(figsize= (10,4)) 
    plot(xt,Qjun_dif)   
    xlabel('t(s)')
    ylabel('Flux difference (m^3/s)')
    title('Junction %d Mass Conservation (Qin-Qout)'%JunNode[i])
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
# Get A of two ends of each pipe
A = [] # all time, all pipes, all A values in grids
pipe_interest=range(0,9)  
'''Here I redefine the pipe_interest vector'''

M_total=n1.M+1
Mi_draw=10000

for m in xrange(0,M_total,Mi_draw) :
    A_tfixed=[] # certain time, all pipes, all A values in grids
    for i in xrange(len(pipe_interest)):
        j = pipe_interest[i]
        N = n1.Ns[j]
        qh = n1.qhist(j) 
        Atemp=[]  #certain time, certain pipe, all A values in grids
        for k in xrange(1,N+1):
            Ak=qh[idx_t(0,k,m,N)]      
            Atemp.append(Ak)
        A_tfixed.append(Atemp)     
    A.append(A_tfixed)
        
#calculate total volumn, i means time, j means pipe number, distance means value of grids  
V_total=[]
for i in xrange(0,M_total,Mi_draw):
    V_total_tfix=[]
    for j in xrange(len(pipe_interest)):
        V_sum=0
        pipe_number=pipe_interest[j]
        delta_x=n1.Ls[pipe_number]/n1.Ns[pipe_number]
        for distance in xrange(len(A[int(i/Mi_draw)][j])):
            V_sum += A[int(i/Mi_draw)][j][distance]*delta_x
        V_total_tfix.append(V_sum)
        print 'Pipe %d during %d s have total flow: %.3f m^3 '%(pipe_number,i*dt,V_sum)
    print 'The total volumn at t=%d s are                      %.3f m^3'%(i*dt,sum(V_total_tfix))
    V_total.append(Q_total_pipefix)
print n1.getTotalVolume()
# Out:
# Pipe 0 during 0 s have total flow: 0.002 m^3
# Pipe 1 during 0 s have total flow: 0.002 m^3
# Pipe 2 during 0 s have total flow: 0.002 m^3
# Pipe 3 during 0 s have total flow: 0.002 m^3
# Pipe 4 during 0 s have total flow: 0.002 m^3
# Pipe 5 during 0 s have total flow: 0.002 m^3
# Pipe 6 during 0 s have total flow: 0.002 m^3
# Pipe 7 during 0 s have total flow: 0.002 m^3
# Pipe 8 during 0 s have total flow: 0.002 m^3
# The total volumn at t=0 s are                      0.019 m^3
# Pipe 0 during 120 s have total flow: 7.175 m^3
# Pipe 1 during 120 s have total flow: 7.035 m^3
# Pipe 2 during 120 s have total flow: 1.213 m^3
# Pipe 3 during 120 s have total flow: 0.002 m^3
# Pipe 4 during 120 s have total flow: 0.002 m^3
# Pipe 5 during 120 s have total flow: 2.133 m^3
# Pipe 6 during 120 s have total flow: 0.435 m^3
# Pipe 7 during 120 s have total flow: 0.000 m^3
# Pipe 8 during 120 s have total flow: 0.000 m^3
# The total volumn at t=120 s are                      17.995 m^3
# Pipe 0 during 240 s have total flow: 7.215 m^3
# Pipe 1 during 240 s have total flow: 7.123 m^3
# Pipe 2 during 240 s have total flow: 7.017 m^3
# Pipe 3 during 240 s have total flow: 5.093 m^3
# Pipe 4 during 240 s have total flow: 0.003 m^3
# Pipe 5 during 240 s have total flow: 2.143 m^3
# Pipe 6 during 240 s have total flow: 2.125 m^3
# Pipe 7 during 240 s have total flow: 0.978 m^3
# Pipe 8 during 240 s have total flow: 0.001 m^3
# The total volumn at t=240 s are                      31.697 m^3
# Pipe 0 during 360 s have total flow: 7.215 m^3
# Pipe 1 during 360 s have total flow: 7.123 m^3
# Pipe 2 during 360 s have total flow: 7.039 m^3
# Pipe 3 during 360 s have total flow: 6.932 m^3
# Pipe 4 during 360 s have total flow: 2.463 m^3
# Pipe 5 during 360 s have total flow: 2.143 m^3
# Pipe 6 during 360 s have total flow: 2.125 m^3
# Pipe 7 during 360 s have total flow: 1.637 m^3
# Pipe 8 during 360 s have total flow: 1.791 m^3
# The total volumn at t=360 s are                      38.468 m^3
# Pipe 0 during 480 s have total flow: 7.222 m^3
# Pipe 1 during 480 s have total flow: 7.131 m^3
# Pipe 2 during 480 s have total flow: 7.083 m^3
# Pipe 3 during 480 s have total flow: 7.069 m^3
# Pipe 4 during 480 s have total flow: 4.643 m^3
# Pipe 5 during 480 s have total flow: 2.146 m^3
# Pipe 6 during 480 s have total flow: 2.127 m^3
# Pipe 7 during 480 s have total flow: 2.122 m^3
# Pipe 8 during 480 s have total flow: 0.876 m^3
# The total volumn at t=480 s are                      40.419 m^3
# Pipe 0 during 600 s have total flow: 7.222 m^3
# Pipe 1 during 600 s have total flow: 7.132 m^3
# Pipe 2 during 600 s have total flow: 7.084 m^3
# Pipe 3 during 600 s have total flow: 7.067 m^3
# Pipe 4 during 600 s have total flow: 5.027 m^3
# Pipe 5 during 600 s have total flow: 2.145 m^3
# Pipe 6 during 600 s have total flow: 2.127 m^3
# Pipe 7 during 600 s have total flow: 2.122 m^3
# Pipe 8 during 600 s have total flow: 1.067 m^3
# The total volumn at t=600 s are                      40.994 m^3
# Pipe 0 during 720 s have total flow: 7.222 m^3
# Pipe 1 during 720 s have total flow: 7.132 m^3
# Pipe 2 during 720 s have total flow: 7.083 m^3
# Pipe 3 during 720 s have total flow: 7.069 m^3
# Pipe 4 during 720 s have total flow: 5.897 m^3
# Pipe 5 during 720 s have total flow: 2.145 m^3
# Pipe 6 during 720 s have total flow: 2.127 m^3
# Pipe 7 during 720 s have total flow: 2.123 m^3
# Pipe 8 during 720 s have total flow: 1.043 m^3
# The total volumn at t=720 s are                      41.842 m^3
# Pipe 0 during 840 s have total flow: 7.222 m^3
# Pipe 1 during 840 s have total flow: 7.132 m^3
# Pipe 2 during 840 s have total flow: 7.084 m^3
# Pipe 3 during 840 s have total flow: 7.069 m^3
# Pipe 4 during 840 s have total flow: 6.262 m^3
# Pipe 5 during 840 s have total flow: 2.145 m^3
# Pipe 6 during 840 s have total flow: 2.127 m^3
# Pipe 7 during 840 s have total flow: 2.123 m^3
# Pipe 8 during 840 s have total flow: 1.509 m^3
# The total volumn at t=840 s are                      42.674 m^3
# Pipe 0 during 960 s have total flow: 7.223 m^3
# Pipe 1 during 960 s have total flow: 7.132 m^3
# Pipe 2 during 960 s have total flow: 7.084 m^3
# Pipe 3 during 960 s have total flow: 7.067 m^3
# Pipe 4 during 960 s have total flow: 6.668 m^3
# Pipe 5 during 960 s have total flow: 2.146 m^3
# Pipe 6 during 960 s have total flow: 2.127 m^3
# Pipe 7 during 960 s have total flow: 2.122 m^3
# Pipe 8 during 960 s have total flow: 1.563 m^3
# The total volumn at t=960 s are                      43.132 m^3
# Pipe 0 during 1080 s have total flow: 7.223 m^3
# Pipe 1 during 1080 s have total flow: 7.133 m^3
# Pipe 2 during 1080 s have total flow: 7.085 m^3
# Pipe 3 during 1080 s have total flow: 7.074 m^3
# Pipe 4 during 1080 s have total flow: 7.073 m^3
# Pipe 5 during 1080 s have total flow: 2.146 m^3
# Pipe 6 during 1080 s have total flow: 2.127 m^3
# Pipe 7 during 1080 s have total flow: 2.123 m^3
# Pipe 8 during 1080 s have total flow: 1.344 m^3
# The total volumn at t=1080 s are                      43.329 m^3
# Pipe 0 during 1200 s have total flow: 7.223 m^3
# Pipe 1 during 1200 s have total flow: 7.133 m^3
# Pipe 2 during 1200 s have total flow: 7.085 m^3
# Pipe 3 during 1200 s have total flow: 7.073 m^3
# Pipe 4 during 1200 s have total flow: 7.071 m^3
# Pipe 5 during 1200 s have total flow: 2.146 m^3
# Pipe 6 during 1200 s have total flow: 2.127 m^3
# Pipe 7 during 1200 s have total flow: 2.123 m^3
# Pipe 8 during 1200 s have total flow: 2.118 m^3
# The total volumn at t=1200 s are                      44.100 m^3
# Pipe 0 during 1320 s have total flow: 7.223 m^3
# Pipe 1 during 1320 s have total flow: 7.133 m^3
# Pipe 2 during 1320 s have total flow: 7.085 m^3
# Pipe 3 during 1320 s have total flow: 7.073 m^3
# Pipe 4 during 1320 s have total flow: 7.071 m^3
# Pipe 5 during 1320 s have total flow: 2.146 m^3
# Pipe 6 during 1320 s have total flow: 2.127 m^3
# Pipe 7 during 1320 s have total flow: 2.122 m^3
# Pipe 8 during 1320 s have total flow: 2.115 m^3
# The total volumn at t=1320 s are                      44.096 m^3
# Pipe 0 during 1440 s have total flow: 7.223 m^3
# Pipe 1 during 1440 s have total flow: 7.133 m^3
# Pipe 2 during 1440 s have total flow: 7.085 m^3
# Pipe 3 during 1440 s have total flow: 7.073 m^3
# Pipe 4 during 1440 s have total flow: 7.071 m^3
# Pipe 5 during 1440 s have total flow: 2.146 m^3
# Pipe 6 during 1440 s have total flow: 2.127 m^3
# Pipe 7 during 1440 s have total flow: 2.123 m^3
# Pipe 8 during 1440 s have total flow: 2.115 m^3
# The total volumn at t=1440 s are                      44.095 m^3
# Pipe 0 during 1560 s have total flow: 7.223 m^3
# Pipe 1 during 1560 s have total flow: 7.133 m^3
# Pipe 2 during 1560 s have total flow: 7.084 m^3
# Pipe 3 during 1560 s have total flow: 7.073 m^3
# Pipe 4 during 1560 s have total flow: 7.071 m^3
# Pipe 5 during 1560 s have total flow: 2.146 m^3
# Pipe 6 during 1560 s have total flow: 2.127 m^3
# Pipe 7 during 1560 s have total flow: 2.123 m^3
# Pipe 8 during 1560 s have total flow: 2.114 m^3
# The total volumn at t=1560 s are                      44.094 m^3
# Pipe 0 during 1680 s have total flow: 7.223 m^3
# Pipe 1 during 1680 s have total flow: 7.132 m^3
# Pipe 2 during 1680 s have total flow: 7.084 m^3
# Pipe 3 during 1680 s have total flow: 7.073 m^3
# Pipe 4 during 1680 s have total flow: 7.071 m^3
# Pipe 5 during 1680 s have total flow: 2.146 m^3
# Pipe 6 during 1680 s have total flow: 2.127 m^3
# Pipe 7 during 1680 s have total flow: 2.123 m^3
# Pipe 8 during 1680 s have total flow: 2.114 m^3
# The total volumn at t=1680 s are                      44.093 m^3
# Pipe 0 during 1800 s have total flow: 7.223 m^3
# Pipe 1 during 1800 s have total flow: 7.133 m^3
# Pipe 2 during 1800 s have total flow: 7.085 m^3
# Pipe 3 during 1800 s have total flow: 7.073 m^3
# Pipe 4 during 1800 s have total flow: 7.071 m^3
# Pipe 5 during 1800 s have total flow: 2.145 m^3
# Pipe 6 during 1800 s have total flow: 2.127 m^3
# Pipe 7 during 1800 s have total flow: 2.122 m^3
# Pipe 8 during 1800 s have total flow: 2.114 m^3
# The total volumn at t=1800 s are                      44.092 m^3
# 44.0920522769

# %%
# illustrate why v is not zero even when empty
def ShowQAofPipeEnd(pipe_detect,time_detect,total_time,total_timestep):
    timestep=int(time_detect/total_time*total_timestep)
    Q=n1.qhist(pipe_detect)[idx_t(1,n1.Ns[pipe_detect],timestep,n1.Ns[pipe_detect])]   #Q at middle of time, end of pipe 4
    A=n1.qhist(pipe_detect)[idx_t(0,n1.Ns[pipe_detect],timestep,n1.Ns[pipe_detect])]   #A at middle of time, end of pipe 4
    print 'At %ds, The Flux at the end of pipe %d is %.8f m^3/s, the water cross area is %.8f m^2 '%(time_detect,pipe_detect,Q,A)
    print 'The velocity is %.8f m/s'%(Q/A)
    
    
ShowQAofPipeEnd(4,1800,n1.T,n1.M)
# Out:
# At 1800s, The Flux at the end of pipe 4 is -0.00207680 m^3/s, the water cross area is 0.07071082 m^2
# The velocity is -0.02937035 m/s

# %%
print Q_in*1800
