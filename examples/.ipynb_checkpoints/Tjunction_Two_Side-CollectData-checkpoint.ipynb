# %% [markdown]
# <p> Run a simulation of filling in a network based on the 7 de Septiembre neighborhood layout in Araijan </p>
# <p>**(.inp and .config files already written)**</p>
# <p> Below you see how to:</p>
# <ul>
# <li>Set boundary and initial conditions </li>
# <li>Run a simulation until time T= 1200 s</li>
# <li>plot time series of pressure head at different points in a single pipe</li>
# <li>plot time series of pressure head at sample points in various pipes</li>
# <li>plot space dependence of pressure head at a certain time</li>
# <li>look at velocities</li>
# <li>plot network layout</li>
# </ul>

# %%
from __future__ import division
import sys
sys.path.append("/home/xin/pipes")   
from allthethings import PyNetwork, PyPipe_ps
from allthethings import PyBC_opt_dh
import numpy as np
import matplotlib.pyplot as plt
#%pylab notebook
# %pylab inline   
from writeit import *
import pickle
import time

def idx_t(i,j,n,N):
    return (2*(N+2)*n+(N+2)*i+j)

# Define a function to get time average to suppress oscillation
# P is the pressure that should be averaged over time
# Mi is how many time steps you want to average 
# dt is the initital time step size
def t_average(P, Mi, dt):
    if Mi == 1:
        return np.linspace(0,n1.T, n1.M+1),P
    n = int(len(P[:-1])/Mi)    # Totally M steps in P{:-1], n=M/Mi, n should be an integer
    x = []          
    P_new = []
    for i in xrange(n):
        P_new.append(np.average(P[i*Mi:(i+1)*Mi-1]))
        x.append((i+0.5)*Mi*dt)
    return x, P_new

#specify input files
fi = "/home/xin/pipes/indata/Xindata/Tpipe_two_side.inp"    
mtype = 1 

# Template for writing files
fc = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_another.config"
with open (fc,"r+") as fread:
    cont = fread.readlines()


# Specify inflow velocities
# v_ins = [0.5, 1., 1.5, 2.5, 3.]
v_ins = [2.]


# Specify different openings for two orifices: [R1, R2, RunningTime]
orifice_info_set = [
      [0.12, 0.03, 1],
      [0.04, 0.16, 1],
      [0.05, 0.1, 1],
      [0.06, 0.09, 1],
      [0.05, 0.08, 1],
      [0.06, 0.06, 1],
      [0.09, 0.06, 1],
      [0.09, 0.03, 1],
      [0.1, 0.05, 1],
      [0.1, 0.06, 1],
      [0.1, 0.08, 1],
      [0.06, 0.1, 1],
      [0.03, 0.15, 1],
      [0.08, 0.05, 1],
      [0.08, 0.04, 1],
      [0.06, 0.04, 1],
      [0.06, 0.03, 1],
]


"""ctrl + ]  means indent"""
t_start = time.time()

for v_in in v_ins:
    for orifice_info in orifice_info_set:

        #------------------------------------------------------------
        # Uisng information to create input files
        #--------------------------------------------------------------
        fc_series = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_another_series.config"
        with open (fc_series,"w") as fwrite:
            for i in xrange(len(cont)):
                if i == 16:
                    r1_line = cont[i].split()
                    r1_line[3] = str(orifice_info[0])
                    r1_line = "        ".join(r1_line)
                    fwrite.write(" "+r1_line)
                    fwrite.write("\n")
                elif i== 17:
                    r2_line = cont[i].split()
                    r2_line[3] = str(orifice_info[1])
                    r2_line = "        ".join(r2_line)
                    fwrite.write(" "+r2_line)  
                    fwrite.write("\n")
                elif i == 21:
                    time_line = cont[i].split()
                    time_line[0] = str(orifice_info[2])
                    time_line[1] = str(orifice_info[2]*20000)
                    time_line = "         ".join(time_line)
                    fwrite.write(time_line)   
                else:
                    fwrite.write(cont[i])

        #------------------------------------------------------------
        # start to build network and run model
        #----------------------------------------------------------------
        n1 = PyNetwork(fi,fc_series,mtype) 
        M = n1.M  
        T = n1.T  

        # Set BC
        q0 = v_in*n1.Ds[0]**2*np.pi/4.        # inflow = 1m/s, used to create the Q0 vector
        Q0 = q0*np.ones(M+1)     
        n1.setbVal(0,Q0)

        # Set IC
        for i in xrange(3):
            A00 = n1.Ds[i]**2*np.pi/4.*np.ones(n1.Ns[i])         # make the IC full
            Q00 = 1e-8*A00    # make the initial v0 = 1e-4
            n1.setIC(i,A00,Q00)


        # Print Some Information
        p1 = PyPipe_ps(n1.Ns[0], n1.Ds[0],n1.Ls[0], M, n1.a[0])
        p_head = p1.pbar(0.25*0.25*3.14,True)
        print "When the pipe is full, the average hydrostatic pressure head is", p_head, "m"
        print "the slot width in pipe 2 is:",9.81*(n1.Ds[2]**2*np.pi/4.)/(n1.a[0]**2)


        # Run simulation
        dt = T/float(M)#time step
        V0 = n1.getTotalVolume()
        n1.runForwardProblem(dt)

        #----------------------------------------------------------------------------
        # Calculate Pressure Head Difference 
        #----------------------------------------------------------------------------

        P0 = n1.pressureTimeSeries(0,n1.Ns[0]-1) 
        P1 = n1.pressureTimeSeries(1,0)
        P2 = n1.pressureTimeSeries(2,0)
        t = np.linspace(0,n1.T, n1.M+1)

        Mi = 200
        fig = plt.figure(figsize= (10,5))
        x0, P0 = t_average(P0, Mi, dt)
        x1, P1 = t_average(P1, Mi, dt)
        x2, P2 = t_average(P2, Mi, dt)
        plt.plot(x0,P0,label = 'P0')
        plt.plot(x1,P1, label = 'P1')
        plt.plot(x2,P2, label = 'P2')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("Pressue Head (m)")
        plt.show()
        time.sleep(1)

        #----------------------------------------------------------------------------
        # Calculate Q1, Q2 distribution
        #----------------------------------------------------------------------------
        # get pipe (A,Q)data
        qh0 = n1.qhist(0)
        qh1 = n1.qhist(1)
        qh2 = n1.qhist(2)
        N = n1.Ns[1]

        Qext0 = [qh0[idx_t(1,0,it,n1.Ns[0])] for it in xrange(n1.M+1)]
        Qext1 = [qh1[idx_t(1,N+1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
        Qext2 = [qh2[idx_t(1,N+1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
        x3, Qext0 = t_average(Qext0, Mi, dt)
        x4, Qext1 = t_average(Qext1, Mi, dt)
        x5, Qext2 = t_average(Qext2, Mi, dt)

        #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
        #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
        fig = plt.figure(figsize= (10,5))
        plt.plot(x3,Qext0, label = 'Pipe 0 outflow')
        plt.plot(x4,Qext1, label = 'Pipe 1 outflow')
        plt.plot(x5,Qext2, label = 'Pipe 2 outflow')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("flux(m^3/s)")
        #plt.ylim(0, 0.3)
        plt.show()
        time.sleep(1)
        
        
        Aext0 = [qh0[idx_t(0,N,it,n1.Ns[0])] for it in xrange(n1.M+1)]
        Aext1 = [qh1[idx_t(0,1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
        Aext2 = [qh2[idx_t(0,1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
        H0_bottom = [p1.HofA(i,True) for i in Aext0]
        H1_bottom = [p1.HofA(i,True) for i in Aext1]
        H2_bottom = [p1.HofA(i,True) for i in Aext2]
        x6, H0_bottom = t_average(H0_bottom, Mi, dt)
        x7, H1_bottom = t_average(H1_bottom, Mi, dt)
        x8, H2_bottom = t_average(H2_bottom, Mi, dt)

        #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
        #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
        fig = plt.figure(figsize= (10,5))
        plt.plot(x6,H0_bottom, label = 'Pipe 0 watre depth')
        plt.plot(x7,H1_bottom, label = 'Pipe 1 water depth')
        plt.plot(x8,H2_bottom, label = 'Pipe 2 water depth')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("Water Depth(m)")
        #plt.ylim(0, 0.3)
        plt.show()
        time.sleep(1)



#         ### Plot Q values for all pipes in a certain time slice
#         track = 1
#         t_interest = 0.723#n1.T-(track-1)*dt
#         M_interest = int((t_interest/n1.T*(n1.M)))    
#         Q_pipe0 = [qh0[idx_t(1,i,M_interest,n1.Ns[0])] for i in xrange(1,n1.Ns[0]+1)]   # 0 and N+1 are ghost grid values
#         Q_pipe1 = [qh1[idx_t(1,i,M_interest,n1.Ns[1])] for i in xrange(1,n1.Ns[1]+1)]  
#         Q_pipe2 = [qh2[idx_t(1,i,M_interest,n1.Ns[2])] for i in xrange(1,n1.Ns[2]+1)]
#         x_Qpipe = []
#         for i in xrange(len(n1.Ls)):
#             x_Qpipe.append( np.linspace(0,n1.Ls[i],n1.Ns[i]) )

        #--------------------------------------------------------------------
        # Print Information
        #---------------------------------------------------------------------
        print "The current orifice inforamtion is ",orifice_info


        print "Now the delta t is ", Mi*dt

        mdx = min([n1.Ls[i]/n1.Ns[i] for i in range(n1.Nedges)])
        print mdx, dt
        print n1.cmax
        print "CFL = 1/(dx/dt)*(max wave speed) = %f" % (max(n1.cmax)*dt/mdx)    

        print "Pressure Head in Pipe 0 is: ",P0[-1], "m","bottom head is:",H0_bottom[-1]
        print "Pressure Head in Pipe 1 is: ",P1[-1], "m","bottom head is:",H1_bottom[-1]
        print "Pressure Head in Pipe 2 is: ",P2[-1], "m","bottom head is:",H2_bottom[-1]

        print "v in Pipe 1 is: ",Qext1[-1]/(n1.Ds[1]**2*np.pi/4. ), "m/s"
        print "v in Pipe 2 is: ",Qext2[-1]/(n1.Ds[2]**2*np.pi/4. ), "m/s"
        
       

        # Check for Dividing Flow
        alpha = 1.
        v0 = Qext0[-1]/(n1.Ds[0]**2*np.pi/4.)
        v1 = Qext1[-1]/(n1.Ds[1]**2*np.pi/4. )
        v2 = Qext2[-1]/(n1.Ds[2]**2*np.pi/4. )
        TH0 = P0[-1]  + (v0)**2/2/9.81*alpha
        TH1 = P1[-1]  + (v1)**2/2/9.81*alpha
        TH2 = P2[-1]  + (v2)**2/2/9.81*alpha
        print "Total Head in Pipe 0 is: ",TH0, "m"
        print "Total Head in Pipe 1 is: ",TH1, "m"
        print "Total Head in Pipe 2 is: ",TH2, "m"

        print "K0-1 =", (TH0-TH1)/(v0**2/2/9.81)
        print "K0-2 =", (TH0-TH2)/(v0**2/2/9.81)

        print "Branch flow ratio =", Qext2[-1]/q0
        print "Re =", v0*n1.Ds[0]/(1.14*1e-6)

        # Make model relax and ready for next round
        n1.reset()
        time.sleep(2)
    
t_end = time.time()
print "The total time is ", t_end-t_start, " s"

# Make sound to remind me that the code has be finished
import subprocess
subprocess.call(['speech-dispatcher'])        #start speech dispatcher
subprocess.call(['spd-say', '"barbar, your process has finished"'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.12, 0.03, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71373945825604, 279.2760689216675, 210.7130759216936]
# CFL = 1/(dx/dt)*(max wave speed) = 0.465460
# Pressure Head in Pipe 0 is:  2.98579583688 m bottom head is: 3.1378717968
# Pressure Head in Pipe 1 is:  3.03558741124 m bottom head is: 3.18773507443
# Pressure Head in Pipe 2 is:  3.01269678056 m bottom head is: 3.16481132849
# v in Pipe 1 is:  1.75789543005 m/s
# v in Pipe 2 is:  0.242110705351 m/s
# Total Head in Pipe 0 is:  3.18966943525 m
# Total Head in Pipe 1 is:  3.19308977326 m
# Total Head in Pipe 2 is:  3.01568442549 m
# K0-1 = -0.016776757982
# K0-2 = 0.853396472834
# Branch flow ratio = 0.121055352676
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.04, 0.16, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71319101013515, 210.71318501894555, 273.7252100495948]
# CFL = 1/(dx/dt)*(max wave speed) = 0.456209
# Pressure Head in Pipe 0 is:  1.95128967345 m bottom head is: 2.10215122063
# Pressure Head in Pipe 1 is:  2.11444171666 m bottom head is: 2.2654599
# Pressure Head in Pipe 2 is:  1.80112961547 m bottom head is: 1.95185854225
# v in Pipe 1 is:  0.311808785191 m/s
# v in Pipe 2 is:  1.68825224807 m/s
# Total Head in Pipe 0 is:  2.15516327182 m
# Total Head in Pipe 1 is:  2.11939710496 m
# Total Head in Pipe 2 is:  1.94639952644 m
# K0-1 = 0.175433048468
# K0-2 = 1.02398617112
# Branch flow ratio = 0.844126124033
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.05, 0.1, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71382690547162, 210.71317182897738, 252.9337885210366]
# CFL = 1/(dx/dt)*(max wave speed) = 0.421556
# Pressure Head in Pipe 0 is:  3.45322077727 m bottom head is: 3.60601779756
# Pressure Head in Pipe 1 is:  3.61909450469 m bottom head is: 3.77217320481
# Pressure Head in Pipe 2 is:  3.37372514722 m bottom head is: 3.52639196234
# v in Pipe 1 is:  0.557973548589 m/s
# v in Pipe 2 is:  1.44203113875 m/s
# Total Head in Pipe 0 is:  3.65709437564 m
# Total Head in Pipe 1 is:  3.63496272492 m
# Total Head in Pipe 2 is:  3.47971157969 m
# K0-1 = 0.108555746767
# K0-2 = 0.870062614119
# Branch flow ratio = 0.721015569374
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.06, 0.09, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71417874531045, 210.7131608208624, 237.09873927683395]
# CFL = 1/(dx/dt)*(max wave speed) = 0.395165
# Pressure Head in Pipe 0 is:  3.52911373533 m bottom head is: 3.6820379565
# Pressure Head in Pipe 1 is:  3.69152899313 m bottom head is: 3.84473493862
# Pressure Head in Pipe 2 is:  3.49333445176 m bottom head is: 3.6461983523
# v in Pipe 1 is:  0.732842205491 m/s
# v in Pipe 2 is:  1.26716200811 m/s
# Total Head in Pipe 0 is:  3.7329873337 m
# Total Head in Pipe 1 is:  3.71890196449 m
# Total Head in Pipe 2 is:  3.57517438829 m
# K0-1 = 0.0690887359632
# K0-2 = 0.774072497251
# Branch flow ratio = 0.633581004056
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.05, 0.08, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.7140878176938, 210.71316396884004, 241.56293352363144]
# CFL = 1/(dx/dt)*(max wave speed) = 0.402605
# Pressure Head in Pipe 0 is:  5.33078261188 m bottom head is: 5.48755777887
# Pressure Head in Pipe 1 is:  5.49440307361 m bottom head is: 5.6516070257
# Pressure Head in Pipe 2 is:  5.28334297208 m bottom head is: 5.43999628108
# v in Pipe 1 is:  0.684098167513 m/s
# v in Pipe 2 is:  1.31590615188 m/s
# Total Head in Pipe 0 is:  5.53465621025 m
# Total Head in Pipe 1 is:  5.51825579037 m
# Total Head in Pipe 2 is:  5.37160031156 m
# K0-1 = 0.0804440595429
# K0-2 = 0.799789183067
# Branch flow ratio = 0.657953075942
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.06, 0.06, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71454083219538, 211.02412846243843, 210.7131031721481]
# CFL = 1/(dx/dt)*(max wave speed) = 0.351707
# Pressure Head in Pipe 0 is:  6.87615973145 m bottom head is: 7.03751013945
# Pressure Head in Pipe 1 is:  7.02374728682 m bottom head is: 7.1855961452
# Pressure Head in Pipe 2 is:  6.89648638011 m bottom head is: 7.05790480072
# v in Pipe 1 is:  1.00464842894 m/s
# v in Pipe 2 is:  0.995355507361 m/s
# Total Head in Pipe 0 is:  7.08003332982 m
# Total Head in Pipe 1 is:  7.0751906337 m
# Total Head in Pipe 2 is:  6.94698243444 m
# K0-1 = 0.0237534244801
# K0-2 = 0.652614641838
# Branch flow ratio = 0.49767775368
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.09, 0.06, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.7146659839892, 238.66006253944445, 210.71307607224526]
# CFL = 1/(dx/dt)*(max wave speed) = 0.397767
# Pressure Head in Pipe 0 is:  3.46256702739 m bottom head is: 3.61537955976
# Pressure Head in Pipe 1 is:  3.58409975678 m bottom head is: 3.73711790528
# Pressure Head in Pipe 2 is:  3.52339081723 m bottom head is: 3.67630534783
# v in Pipe 1 is:  1.28393532669 m/s
# v in Pipe 2 is:  0.71606892221 m/s
# Total Head in Pipe 0 is:  3.66644062576 m
# Total Head in Pipe 1 is:  3.66812064991 m
# Total Head in Pipe 2 is:  3.54952510374 m
# K0-1 = -0.00824051846092
# K0-2 = 0.573470635479
# Branch flow ratio = 0.358034461105
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.09, 0.03, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71417274963554, 271.33726713271625, 210.7130866382948]
# CFL = 1/(dx/dt)*(max wave speed) = 0.452229
# Pressure Head in Pipe 0 is:  5.97756795306 m bottom head is: 6.13611496764
# Pressure Head in Pipe 1 is:  6.04472122538 m bottom head is: 6.20346399995
# Pressure Head in Pipe 2 is:  6.03639866987 m bottom head is: 6.19511706269
# v in Pipe 1 is:  1.66059969193 m/s
# v in Pipe 2 is:  0.339405910867 m/s
# Total Head in Pipe 0 is:  6.18144155143 m
# Total Head in Pipe 1 is:  6.18527124255 m
# Total Head in Pipe 2 is:  6.04227004461 m
# K0-1 = -0.0187846349553
# K0-2 = 0.682636240963
# Branch flow ratio = 0.169702955433
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.1, 0.02, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.7131910030152, 284.39031416706655, 210.71309423219827]
# CFL = 1/(dx/dt)*(max wave speed) = 0.473984
# Pressure Head in Pipe 0 is:  5.39140310679 m bottom head is: 5.54833560054
# Pressure Head in Pipe 1 is:  5.42841881809 m bottom head is: 5.58544826666
# Pressure Head in Pipe 2 is:  5.36800358671 m bottom head is: 5.52487513809
# v in Pipe 1 is:  1.82393826149 m/s
# v in Pipe 2 is:  0.176068267898 m/s
# Total Head in Pipe 0 is:  5.59527670516 m
# Total Head in Pipe 1 is:  5.59797798128 m
# Total Head in Pipe 2 is:  5.36958360888 m
# K0-1 = -0.0132497593477
# K0-2 = 1.10702463725
# Branch flow ratio = 0.0880341339489
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.1, 0.05, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71457262106858, 254.29505570691666, 210.7130854391006]
# CFL = 1/(dx/dt)*(max wave speed) = 0.423825
# Pressure Head in Pipe 0 is:  3.34459825716 m bottom head is: 3.49721814266
# Pressure Head in Pipe 1 is:  3.44378266488 m bottom head is: 3.59656406418
# Pressure Head in Pipe 2 is:  3.4171066826 m bottom head is: 3.56984416715
# v in Pipe 1 is:  1.45762121816 m/s
# v in Pipe 2 is:  0.542383522747 m/s
# Total Head in Pipe 0 is:  3.54847185552 m
# Total Head in Pipe 1 is:  3.55207316517 m
# Total Head in Pipe 2 is:  3.43210056056 m
# K0-1 = -0.0176644238168
# K0-2 = 0.570801201778
# Branch flow ratio = 0.271191761373
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.1, 0.06, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71465015798896, 244.66550271689005, 210.71307913663878]
# CFL = 1/(dx/dt)*(max wave speed) = 0.407776
# Pressure Head in Pipe 0 is:  2.82683319931 m bottom head is: 2.9786883896
# Pressure Head in Pipe 1 is:  2.9405575975 m bottom head is: 3.09256946679
# Pressure Head in Pipe 2 is:  2.89368343762 m bottom head is: 3.04562995868
# v in Pipe 1 is:  1.34915128565 m/s
# v in Pipe 2 is:  0.650853121926 m/s
# Total Head in Pipe 0 is:  3.03070679767 m
# Total Head in Pipe 1 is:  3.03333074692 m
# Total Head in Pipe 2 is:  2.91527415048 m
# K0-1 = -0.0128704710494
# K0-2 = 0.566197134498
# Branch flow ratio = 0.325426560963
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.09, 0.02, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71343441324544, 282.35137263349844, 210.7130847047149]
# CFL = 1/(dx/dt)*(max wave speed) = 0.470586
# Pressure Head in Pipe 0 is:  7.06056619189 m bottom head is: 7.22254107146
# Pressure Head in Pipe 1 is:  7.10247428795 m bottom head is: 7.26459342015
# Pressure Head in Pipe 2 is:  7.06054310861 m bottom head is: 7.22251790896
# v in Pipe 1 is:  1.79861703373 m/s
# v in Pipe 2 is:  0.201389336491 m/s
# Total Head in Pipe 0 is:  7.26443979026 m
# Total Head in Pipe 1 is:  7.26735824484 m
# Total Head in Pipe 2 is:  7.06261026788 m
# K0-1 = -0.0143150197031
# K0-2 = 0.989973807267
# Branch flow ratio = 0.100694668246
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.1, 0.08, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.7146518083231, 227.2857496657267, 210.71308639620094]
# CFL = 1/(dx/dt)*(max wave speed) = 0.378810
# Pressure Head in Pipe 0 is:  2.03693184279 m bottom head is: 2.1878739831
# Pressure Head in Pipe 1 is:  2.17138456723 m bottom head is: 2.32246049441
# Pressure Head in Pipe 2 is:  2.08328268771 m bottom head is: 2.23426994733
# v in Pipe 1 is:  1.16406588352 m/s
# v in Pipe 2 is:  0.835938371735 m/s
# Total Head in Pipe 0 is:  2.24080544116 m
# Total Head in Pipe 1 is:  2.24044926556 m
# Total Head in Pipe 2 is:  2.1188990466 m
# K0-1 = 0.00174704131974
# K0-2 = 0.597950865323
# Branch flow ratio = 0.417969185868
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.06, 0.1, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71406386464645, 210.71316492739538, 242.8846682315534]
# CFL = 1/(dx/dt)*(max wave speed) = 0.404808
# Pressure Head in Pipe 0 is:  2.90888799932 m bottom head is: 3.06085559916
# Pressure Head in Pipe 1 is:  3.07313446446 m bottom head is: 3.22533700318
# Pressure Head in Pipe 2 is:  2.8581507117 m bottom head is: 3.01004841477
# v in Pipe 1 is:  0.670449596499 m/s
# v in Pipe 2 is:  1.32955476026 m/s
# Total Head in Pipe 0 is:  3.11276159769 m
# Total Head in Pipe 1 is:  3.09604489572 m
# Total Head in Pipe 2 is:  2.94824836004 m
# K0-1 = 0.0819954231552
# K0-2 = 0.806937430675
# Branch flow ratio = 0.664777380128
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.03, 0.15, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.713118483149, 210.71318990415517, 282.35179098774137]
# CFL = 1/(dx/dt)*(max wave speed) = 0.470586
# Pressure Head in Pipe 0 is:  1.93400978854 m bottom head is: 2.0848555109
# Pressure Head in Pipe 1 is:  2.09302432452 m bottom head is: 2.24402120102
# Pressure Head in Pipe 2 is:  1.74965030203 m bottom head is: 1.90033630911
# v in Pipe 1 is:  0.203746638305 m/s
# v in Pipe 2 is:  1.7962597273 m/s
# Total Head in Pipe 0 is:  2.13788338691 m
# Total Head in Pipe 1 is:  2.09514016003 m
# Total Head in Pipe 2 is:  1.91410234117 m
# K0-1 = 0.209655527833
# K0-2 = 1.09764602934
# Branch flow ratio = 0.898129863649
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.08, 0.05, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71465414171365, 242.57481791076145, 210.71307743936939]
# CFL = 1/(dx/dt)*(max wave speed) = 0.404291
# Pressure Head in Pipe 0 is:  5.2533413362 m bottom head is: 5.40991815154
# Pressure Head in Pipe 1 is:  5.36960360929 m bottom head is: 5.52647931923
# Pressure Head in Pipe 2 is:  5.31800109216 m bottom head is: 5.47474331836
# v in Pipe 1 is:  1.32698282379 m/s
# v in Pipe 2 is:  0.673021522786 m/s
# Total Head in Pipe 0 is:  5.45721493457 m
# Total Head in Pipe 1 is:  5.4593530188 m
# Total Head in Pipe 2 is:  5.34108763498 m
# K0-1 = -0.0104873031702
# K0-2 = 0.569604404497
# Branch flow ratio = 0.336510761393
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.08, 0.04, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71456211633216, 254.6387900849798, 210.7130854920026]
# CFL = 1/(dx/dt)*(max wave speed) = 0.424398
# Pressure Head in Pipe 0 is:  6.44251538143 m bottom head is: 6.60246329202
# Pressure Head in Pipe 1 is:  6.54075695307 m bottom head is: 6.70101448567
# Pressure Head in Pipe 2 is:  6.51463645163 m bottom head is: 6.6748111981
# v in Pipe 1 is:  1.46267522335 m/s
# v in Pipe 2 is:  0.537329530258 m/s
# Total Head in Pipe 0 is:  6.64638897979 m
# Total Head in Pipe 1 is:  6.64979970582 m
# Total Head in Pipe 2 is:  6.5293522021 m
# K0-1 = -0.0167296111449
# K0-2 = 0.574065394609
# Branch flow ratio = 0.268664765129
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.06, 0.04, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71465265063773, 238.75772823547237, 210.7130760581814]
# CFL = 1/(dx/dt)*(max wave speed) = 0.397930
# Pressure Head in Pipe 0 is:  11.4691683441 m bottom head is: 11.6510642244
# Pressure Head in Pipe 1 is:  11.5895748786 m bottom head is: 11.7721494256
# Pressure Head in Pipe 2 is:  11.5292370973 m bottom head is: 11.7114706572
# v in Pipe 1 is:  1.28751385511 m/s
# v in Pipe 2 is:  0.712490389541 m/s
# Total Head in Pipe 0 is:  11.6730419425 m
# Total Head in Pipe 1 is:  11.6740647831 m
# Total Head in Pipe 2 is:  11.5551108259 m
# K0-1 = -0.00501703344832
# K0-2 = 0.578452126934
# Branch flow ratio = 0.356245194771
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# The current orifice inforamtion is  [0.06, 0.03, 1]
# Now the delta t is  0.01
# 0.03 5e-05
# [210.71454317047582, 254.74752816053507, 210.713085198699]
# CFL = 1/(dx/dt)*(max wave speed) = 0.424579
# Pressure Head in Pipe 0 is:  14.9669639593 m bottom head is: 15.1714963409
# Pressure Head in Pipe 1 is:  15.063978792 m bottom head is: 15.2692253348
# Pressure Head in Pipe 2 is:  15.0377952393 m bottom head is: 15.2428485761
# v in Pipe 1 is:  1.4669929782 m/s
# v in Pipe 2 is:  0.5330117768 m/s
# Total Head in Pipe 0 is:  15.1708375576 m
# Total Head in Pipe 1 is:  15.1736662741 m
# Total Head in Pipe 2 is:  15.0522754408 m
# K0-1 = -0.0138748543847
# K0-2 = 0.58154718304
# Branch flow ratio = 0.2665058884
# Re = 526315.789474
# The total time is  840.597472906  s
# 0

# %%
oris = np.arange(0.01, 0.11, 0.01)
for ori in oris:
    Atao = p1.AofH(0.83*ori,True)
    Q = 0.3**2*np.pi/4.*1.
    H = (Q/0.78/Atao)**2/2/9.81+0.83*ori
    print ori, H
