# %% [markdown]
# <p> Run a simulation of filling in a network based on the 7 de Septiembre neighborhood layout in Araijan </p>
# <p>**(.inp and .config files already written)**</p>
# <p> Below you see how to:</p>
# <ul>
# <li>Set boundary and initial conditions </li>
# <li>Run a simulation until time T= 1200 s</li>
# <li>plot time series of pressure head at different points in a single pipe</li>
# <li>plot time series of pressure head at sample points in various pipes</li>
# <li>plot space dependence of pressure head at a certain time</li>
# <li>look at velocities</li>
# <li>plot network layout</li>
# </ul>

# %%
from __future__ import division
import sys
sys.path.append("/home/xin/pipes")   
from allthethings import PyNetwork, PyPipe_ps
from allthethings import PyBC_opt_dh
import numpy as np
import matplotlib.pyplot as plt
#%pylab notebook
# %pylab inline   
from writeit import *
import pickle
import time

def idx_t(i,j,n,N):
    return (2*(N+2)*n+(N+2)*i+j)

# Define a function to get time average to suppress oscillation
# P is the pressure that should be averaged over time
# Mi is how many time steps you want to average 
# dt is the initital time step size
def t_average(P, Mi, dt):
    if Mi == 1:
        return np.linspace(0,n1.T, n1.M+1),P
    n = int(len(P[:-1])/Mi)    # Totally M steps in P{:-1], n=M/Mi, n should be an integer
    x = []          
    P_new = []
    for i in xrange(n):
        P_new.append(np.average(P[i*Mi:(i+1)*Mi-1]))
        x.append((i+0.5)*Mi*dt)
    return x, P_new


# the regressed function from experimental results (main pipes)
def get_error(branch_flow_ratio, Kmain):
    y = -0.6664*branch_flow_ratio**3 + 1.6609*branch_flow_ratio**2 - 0.7095*branch_flow_ratio + 0.0373
    error = (y - Kmain)**2
    return error


#specify input files
fi = "/home/xin/pipes/indata/Xindata/Tpipe_two_side.inp"    
mtype = 1 

# Template for writing files
fc = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_another.config"
with open (fc,"r+") as fread:
    cont = fread.readlines()


# Specify different openings for two orifices: [R1, R2, RunningTime]
orifice_info_set = [
#     [0.1, 0.09, 20],
#     [0.1, 0.08, 20],
#     [0.1, 0.07, 20],
#     [0.1, 0.05, 20],
#     #[0.1, 0.03, 20],         #This line crashes code
#     [0.09, 0.1, 20],
#     [0.08, 0.1, 20],
#     [0.07, 0.1, 20],
#     [0.06, 0.1, 20],
#     [0.04, 0.1, 20],
#     [0.03, 0.1, 20],
    
      [0.1, 0.04, 20],    
      [0.1, 0.02, 20],
      [0.1, 0.01, 20],
      [0.09, 0.03, 20],    # the first four are easy to crash
      [0.03, 0.3, 60],
      [0.05, 0.3, 20],
      [0.03, 0.2, 60],
      [0.05, 0.2, 20],
      [0.04, 0.16, 80],
      [0.05, 0.1, 20],
      [0.06, 0.09, 20],
      [0.05, 0.08, 20],
      [0.06, 0.06, 20],
      [0.07, 0.07, 20],
      [0.08, 0.08, 20],
      [0.09, 0.06, 20],
      [0.1, 0.06, 20],
      [0.08, 0.03, 20],
      [0.08, 0.02, 20],
      [0.08, 0.01, 30],
      [0.09, 0.01 ,30],
    
]


"""ctrl + ]  means indent"""
N_error = 0  # used to count how many points can be used to calculate errors
tol = 5e-3  # tolerance for oscilations, check whether the final state is steady
error = 0.  # the total error



t_start = time.time()
for orifice_info in orifice_info_set:
    
    #------------------------------------------------------------
    # Uisng information to create input files
    #--------------------------------------------------------------
    fc_series = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_another_series.config"
    with open (fc_series,"w") as fwrite:
        for i in xrange(len(cont)):
            if i == 16:
                r1_line = cont[i].split()
                r1_line[3] = str(orifice_info[0])
                r1_line = "        ".join(r1_line)
                fwrite.write(" "+r1_line)
                fwrite.write("\n")
            elif i== 17:
                r2_line = cont[i].split()
                r2_line[3] = str(orifice_info[1])
                r2_line = "        ".join(r2_line)
                fwrite.write(" "+r2_line)  
                fwrite.write("\n")
            elif i == 21:
                time_line = cont[i].split()
                time_line[0] = str(orifice_info[2])
                time_line[1] = str(orifice_info[2]*1000)
                time_line = "         ".join(time_line)
                fwrite.write(time_line)   
            else:
                fwrite.write(cont[i])
            
    #------------------------------------------------------------
    # start to build network and run model
    #----------------------------------------------------------------
    n1 = PyNetwork(fi,fc_series,mtype) 
    M = n1.M  
    T = n1.T  

    # Set BC
    v_in = 2.
    q0 = v_in*n1.Ds[0]**2*np.pi/4.        # inflow = 1m/s, used to create the Q0 vector
    Q0 = q0*np.ones(M+1)     
    n1.setbVal(0,Q0)

    # Set IC
    for i in xrange(3):
        A00 = n1.Ds[i]**2*np.pi/4.*np.ones(n1.Ns[i])         # make the IC full
        Q00 = 1e-8*A00    # make the initial v0 = 1e-4
        n1.setIC(i,A00,Q00)


    # Print Some Information
#     p1 = PyPipe_ps(n1.Ns[0], n1.Ds[0],n1.Ls[0], M, n1.a[0])
#     p_head = p1.pbar(0.25*0.25*3.14,True)
#     print "When the pipe is full, the average hydrostatic pressure head is", p_head, "m"
#     print "the slot width in pipe 2 is:",9.81*(n1.Ds[2]**2*np.pi/4.)/(n1.a[0]**2)


    # Run simulation
    dt = T/float(M)#time step
    V0 = n1.getTotalVolume()
    n1.runForwardProblem(dt)

    #----------------------------------------------------------------------------
    # Calculate Pressure Head Difference 
    #----------------------------------------------------------------------------

    P0 = n1.pressureTimeSeries(0,n1.Ns[0]-1) 
    P1 = n1.pressureTimeSeries(1,0)
    P2 = n1.pressureTimeSeries(2,0)
    t = np.linspace(0,n1.T, n1.M+1)

    Mi = 500
    fig = plt.figure(figsize= (10,5))
    x0, P0 = t_average(P0, Mi, dt)
    x1, P1 = t_average(P1, Mi, dt)
    x2, P2 = t_average(P2, Mi, dt)
    plt.plot(x0,P0,label = 'P0')
    plt.plot(x1,P1, label = 'P1')
    plt.plot(x2,P2, label = 'P2')
    plt.legend(loc='best')
    plt.xlabel("time")
    plt.ylabel("Pressue Head (m)")
    plt.show()
    time.sleep(1)
  
    #----------------------------------------------------------------------------
    # Calculate Q1, Q2 distribution
    #----------------------------------------------------------------------------
    # get pipe (A,Q)data
    qh0 = n1.qhist(0)
    qh1 = n1.qhist(1)
    qh2 = n1.qhist(2)
    N = n1.Ns[1]
    
    Qext0 = [qh0[idx_t(1,0,it,n1.Ns[0])] for it in xrange(n1.M+1)]
    Qext1 = [qh1[idx_t(1,N+1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
    Qext2 = [qh2[idx_t(1,N+1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
    x3, Qext0 = t_average(Qext0, Mi, dt)
    x4, Qext1 = t_average(Qext1, Mi, dt)
    x5, Qext2 = t_average(Qext2, Mi, dt)

    #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
    #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
    fig = plt.figure(figsize= (10,5))
    plt.plot(x3,Qext0, label = 'Pipe 0 outflow')
    plt.plot(x4,Qext1, label = 'Pipe 1 outflow')
    plt.plot(x5,Qext2, label = 'Pipe 2 outflow')
    plt.legend(loc='best')
    plt.xlabel("time")
    plt.ylabel("flux(m^3/s)")
    #plt.ylim(0, 0.3)
    plt.show()
    time.sleep(1)


    ### Plot Q values for all pipes in a certain time slice
    track = 1
    t_interest = 0.723#n1.T-(track-1)*dt
    M_interest = int((t_interest/n1.T*(n1.M)))    
    Q_pipe0 = [qh0[idx_t(1,i,M_interest,n1.Ns[0])] for i in xrange(1,n1.Ns[0]+1)]   # 0 and N+1 are ghost grid values
    Q_pipe1 = [qh1[idx_t(1,i,M_interest,n1.Ns[1])] for i in xrange(1,n1.Ns[1]+1)]  
    Q_pipe2 = [qh2[idx_t(1,i,M_interest,n1.Ns[2])] for i in xrange(1,n1.Ns[2]+1)]
    x_Qpipe = []
    for i in xrange(len(n1.Ls)):
        x_Qpipe.append( np.linspace(0,n1.Ls[i],n1.Ns[i]) )

    #--------------------------------------------------------------------
    # Print Information
    #---------------------------------------------------------------------
    print "The current orifice inforamtion is ",orifice_info
   
    
#     print "Now the delta t is ", Mi*dt
    
#     mdx = min([n1.Ls[i]/n1.Ns[i] for i in range(n1.Nedges)])
#     print mdx, dt
#     print n1.cmax
#     print "CFL = 1/(dx/dt)*(max wave speed) = %f" % (max(n1.cmax)*dt/mdx)    
    
#     print "Pressure Head in Pipe 0 is: ",P0[-1], "m"
#     print "Pressure Head in Pipe 1 is: ",P1[-1], "m"
#     print "Pressure Head in Pipe 2 is: ",P2[-1], "m"

    print "v in Pipe 1 is: ",Qext1[-1]/(n1.Ds[1]**2*np.pi/4. ), "m/s"
    print "v in Pipe 2 is: ",Qext2[-1]/(n1.Ds[2]**2*np.pi/4. ), "m/s"

    # Check for Dividing Flow
    alpha = 1.
    v0 = Qext0[-1]/(n1.Ds[0]**2*np.pi/4.)
    v1 = Qext1[-1]/(n1.Ds[1]**2*np.pi/4. )
    v2 = Qext2[-1]/(n1.Ds[2]**2*np.pi/4. )
    TH0 = P0[-1]  + (v0)**2/2/9.81*alpha
    TH1 = P1[-1]  + (v1)**2/2/9.81*alpha
    TH2 = P2[-1]  + (v2)**2/2/9.81*alpha
#     print "Total Head in Pipe 0 is: ",TH0, "m"
#     print "Total Head in Pipe 1 is: ",TH1, "m"
#     print "Total Head in Pipe 2 is: ",TH2, "m"

    K01 = (TH0-TH1)/(v0**2/2/9.81)
    K02 = (TH0-TH2)/(v0**2/2/9.81)
    bfr = Qext2[-1]/q0
    print "K0-1 =", K01
    print "K0-2 =", K02
    print "Branch flow ratio =", bfr
#     print "Re =", v0*n1.Ds[0]/(1.14*1e-6)
    
    
    add_error = get_error(bfr, K01)
    print "add_error for this orifice is", add_error
    if abs(P0[-1]-P0[-2])<tol and abs(P1[-1]-P1[-2])<tol and abs(P2[-1]-P2[-2])<tol:
        print "Steady State Check Passed"
        N_error += 1
        error += add_error
        print "current N is:",N_error
        print "current error is:", error
    
    # Make model relax and ready for next round
    n1.reset()
    time.sleep(2)
        
t_end = time.time()
print "The total time is ", t_end-t_start, " s"

print "total error is ", error
print "N is ",N_error
avg_error = np.sqrt(error/N_error)    # simulate the formula for standard deviation
print "The average error is ", avg_error


# Make sound to remind me that the code has be finished
import subprocess
subprocess.call(['speech-dispatcher'])        #start speech dispatcher
subprocess.call(['spd-say', '"barbar, your process has finished"'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The current orifice inforamtion is  [0.1, 0.04, 20]
# v in Pipe 1 is:  1.58421340505 m/s
# v in Pipe 2 is:  0.416022893438 m/s
# K0-1 = 0.0210490138907
# K0-2 = 1.23750871259
# Branch flow ratio = 0.208011446719
# add_error for this orifice is 0.00428578585201
# Steady State Check Passed
# current N is: 1
# current error is: 0.00428578585201
# The current orifice inforamtion is  [0.1, 0.02, 20]
# v in Pipe 1 is:  1.82387838848 m/s
# v in Pipe 2 is:  0.175964423628 m/s
# K0-1 = 0.0342815760283
# K0-2 = 1.02126475631
# Branch flow ratio = 0.087982211814
# add_error for this orifice is 0.0022091882486
# Steady State Check Passed
# current N is: 2
# current error is: 0.00649497410061
# The current orifice inforamtion is  [0.1, 0.01, 20]
# v in Pipe 1 is:  2.05086407851 m/s
# v in Pipe 2 is:  0.0469847573602 m/s
# K0-1 = 0.402434696152
# K0-2 = 12.2490091742
# Branch flow ratio = 0.0234923786801
# add_error for this orifice is 0.145080651886
# The current orifice inforamtion is  [0.09, 0.03, 20]
# v in Pipe 1 is:  1.66437975964 m/s
# v in Pipe 2 is:  0.335789945309 m/s
# K0-1 = 0.0909214695381
# K0-2 = 1.14446082441
# Branch flow ratio = 0.167894972654
# add_error for this orifice is 0.016661183157
# Steady State Check Passed
# current N is: 3
# current error is: 0.0231561572576
# The current orifice inforamtion is  [0.03, 0.3, 60]
# v in Pipe 1 is:  0.121205545031 m/s
# v in Pipe 2 is:  1.88631192108 m/s
# K0-1 = 0.162337031229
# K0-2 = 0.0386046430058
# Branch flow ratio = 0.943155960542
# add_error for this orifice is 0.0154110277089
# Steady State Check Passed
# current N is: 4
# current error is: 0.0385671849665
# The current orifice inforamtion is  [0.05, 0.3, 20]
# v in Pipe 1 is:  0.245491174923 m/s
# v in Pipe 2 is:  1.75462483719 m/s
# K0-1 = 0.0133813100834
# K0-2 = 0.0251468723433
# Branch flow ratio = 0.877312418597
# add_error for this orifice is 0.0528252379983
# Steady State Check Passed
# current N is: 5
# current error is: 0.0913924229649
# The current orifice inforamtion is  [0.03, 0.2, 60]
# v in Pipe 1 is:  0.140203701914 m/s
# v in Pipe 2 is:  1.86465237473 m/s
# K0-1 = 0.331722231152
# K0-2 = 0.27597732727
# Branch flow ratio = 0.932326187365
# add_error for this orifice is 0.00273067248302
# Steady State Check Passed
# current N is: 6
# current error is: 0.0941230954479
# The current orifice inforamtion is  [0.05, 0.2, 20]
# v in Pipe 1 is:  0.298004142394 m/s
# v in Pipe 2 is:  1.7020305849 m/s
# K0-1 = 0.0256428226889
# K0-2 = 0.064435787824
# Branch flow ratio = 0.851015292448
# add_error for this orifice is 0.0400037340693
# Steady State Check Passed
# current N is: 7
# current error is: 0.134126829517
# The current orifice inforamtion is  [0.04, 0.16, 80]
# v in Pipe 1 is:  0.256000748409 m/s
# v in Pipe 2 is:  1.744898171 m/s
# K0-1 = 0.349851302546
# K0-2 = 0.560793959924
# Branch flow ratio = 0.872449085502
# add_error for this orifice is 0.0120722446304
# Steady State Check Passed
# current N is: 8
# current error is: 0.146199074148
# The current orifice inforamtion is  [0.05, 0.1, 20]
# v in Pipe 1 is:  0.554730800565 m/s
# v in Pipe 2 is:  1.4454142784 m/s
# K0-1 = 0.260612524113
# K0-2 = 0.402589142047
# Branch flow ratio = 0.722707139198
# add_error for this orifice is 0.014429900764
# Steady State Check Passed
# current N is: 9
# current error is: 0.160628974912
# The current orifice inforamtion is  [0.06, 0.09, 20]
# v in Pipe 1 is:  0.732958192071 m/s
# v in Pipe 2 is:  1.26709395643 m/s
# K0-1 = 0.1713627631
# K0-2 = 0.523717063527
# Branch flow ratio = 0.633546978216
# add_error for this orifice is 0.00745995270853
# Steady State Check Passed
# current N is: 10
# current error is: 0.16808892762
# The current orifice inforamtion is  [0.05, 0.08, 20]
# v in Pipe 1 is:  0.683000828431 m/s
# v in Pipe 2 is:  1.31717273703 m/s
# K0-1 = 0.366571012798
# K0-2 = 0.533229957866
# Branch flow ratio = 0.658586368514
# add_error for this orifice is 0.0710248175162
# Steady State Check Passed
# current N is: 11
# current error is: 0.239113745136
# The current orifice inforamtion is  [0.06, 0.06, 20]
# v in Pipe 1 is:  1.00784599691 m/s
# v in Pipe 2 is:  0.992099501488 m/s
# K0-1 = 0.348070236698
# K0-2 = 0.831561558762
# Branch flow ratio = 0.496049750744
# add_error for this orifice is 0.112472238016
# Steady State Check Passed
# current N is: 12
# current error is: 0.351585983152
# The current orifice inforamtion is  [0.07, 0.07, 20]
# v in Pipe 1 is:  1.0127844287 m/s
# v in Pipe 2 is:  0.987258288196 m/s
# K0-1 = 0.16328110477
# K0-2 = 0.808215982453
# Branch flow ratio = 0.493629144098
# add_error for this orifice is 0.0229995939787
# Steady State Check Passed
# current N is: 13
# current error is: 0.374585577131
# The current orifice inforamtion is  [0.08, 0.08, 20]
# v in Pipe 1 is:  1.01897586714 m/s
# v in Pipe 2 is:  0.981072741238 m/s
# K0-1 = 0.00559010039522
# K0-2 = 0.771902929155
# Branch flow ratio = 0.490536370619
# add_error for this orifice is 2.18174526138e-05
# Steady State Check Passed
# current N is: 14
# current error is: 0.374607394583
# The current orifice inforamtion is  [0.09, 0.06, 20]
# v in Pipe 1 is:  1.29622181523 m/s
# v in Pipe 2 is:  0.703830065005 m/s
# K0-1 = 0.0138505140793
# K0-2 = 1.07604141648
# Branch flow ratio = 0.351915032502
# add_error for this orifice is 0.00245866036315
# Steady State Check Passed
# current N is: 15
# current error is: 0.377066054946
# The current orifice inforamtion is  [0.1, 0.06, 20]
# v in Pipe 1 is:  1.36467284717 m/s
# v in Pipe 2 is:  0.635384677875 m/s
# K0-1 = -0.0555827139644
# K0-2 = 1.14030988257
# Branch flow ratio = 0.317692338938
# add_error for this orifice is 0.000188909687423
# Steady State Check Passed
# current N is: 16
# current error is: 0.377254964634
# The current orifice inforamtion is  [0.08, 0.03, 20]
# v in Pipe 1 is:  1.6148076648 m/s
# v in Pipe 2 is:  0.385137327759 m/s
# K0-1 = 0.160964002795
# K0-2 = 1.13343313129
# Branch flow ratio = 0.19256866388
# add_error for this orifice is 0.0413957958018
# Steady State Check Passed
# current N is: 17
# current error is: 0.418650760436
# The current orifice inforamtion is  [0.08, 0.02, 20]
# v in Pipe 1 is:  1.76619108706 m/s
# v in Pipe 2 is:  0.232903052092 m/s
# K0-1 = 0.121767692195
# K0-2 = 1.03252746272
# Branch flow ratio = 0.116451526046
# add_error for this orifice is 0.0212049018873
# Steady State Check Passed
# current N is: 18
# current error is: 0.439855662323
# The current orifice inforamtion is  [0.08, 0.01, 30]
# v in Pipe 1 is:  1.90934968668 m/s
# v in Pipe 2 is:  0.090566365536 m/s
# K0-1 = 0.0494675663832
# K0-2 = 0.807854515504
# Branch flow ratio = 0.045283182768
# add_error for this orifice is 0.00167707267475
# Steady State Check Passed
# current N is: 19
# current error is: 0.441532734998
# The current orifice inforamtion is  [0.09, 0.01, 30]
# v in Pipe 1 is:  1.9226882202 m/s
# v in Pipe 2 is:  0.0774254224745 m/s
# K0-1 = 0.0257574357732
# K0-2 = 0.760862225999
# Branch flow ratio = 0.0387127112373
# add_error for this orifice is 0.000181538429134
# Steady State Check Passed
# current N is: 20
# current error is: 0.441714273427
# The current orifice inforamtion is  [0.1, 0.08, 20]
# v in Pipe 1 is:  1.18144340435 m/s
# v in Pipe 2 is:  0.818611089397 m/s
# K0-1 = -0.143509915498
# K0-2 = 0.906183196235
# Branch flow ratio = 0.409305544698
# add_error for this orifice is 0.0151201331159
# Steady State Check Passed
# current N is: 21
# current error is: 0.456834406543
# The current orifice inforamtion is  [0.1, 0.05, 20]
# v in Pipe 1 is:  1.47125317458 m/s
# v in Pipe 2 is:  0.52901267679 m/s
# K0-1 = -0.0108650026042
# K0-2 = 1.27729639791
# Branch flow ratio = 0.264506338395
# add_error for this orifice is 0.00126963744793
# Steady State Check Passed
# current N is: 22
# current error is: 0.458104043991
# The current orifice inforamtion is  [0.06, 0.1, 20]
# v in Pipe 1 is:  0.669027892464 m/s
# v in Pipe 2 is:  1.33103073806 m/s
# K0-1 = 0.119992106533
# K0-2 = 0.440374585708
# Branch flow ratio = 0.665515369029
# add_error for this orifice is 0.000245721917615
# Steady State Check Passed
# current N is: 23
# current error is: 0.458349765908
# The current orifice inforamtion is  [0.08, 0.008, 40]
# v in Pipe 1 is:  1.93491695104 m/s
# v in Pipe 2 is:  0.0651322909614 m/s
# K0-1 = 0.0455499408239
# K0-2 = 1.17087048389
# Branch flow ratio = 0.0325661454807
# add_error for this orifice is 0.000877176368287
# Steady State Check Passed
# current N is: 24
# current error is: 0.459226942277
# The total time is  1368.65688491  s
# total error is  0.459226942277
# N is  24
# The average error is  0.138327350615
# 0
