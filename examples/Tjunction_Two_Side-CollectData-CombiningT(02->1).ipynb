# %% [markdown]
# <p> Run a simulation of filling in a network based on the 7 de Septiembre neighborhood layout in Araijan </p>
# <p>**(.inp and .config files already written)**</p>
# <p> Below you see how to:</p>
# <ul>
# <li>Set boundary and initial conditions </li>
# <li>Run a simulation until time T= 1200 s</li>
# <li>plot time series of pressure head at different points in a single pipe</li>
# <li>plot time series of pressure head at sample points in various pipes</li>
# <li>plot space dependence of pressure head at a certain time</li>
# <li>look at velocities</li>
# <li>plot network layout</li>
# </ul>

# %%
from __future__ import division
import sys
sys.path.append("/home/xin/pipes")   
from allthethings import PyNetwork, PyPipe_ps
from allthethings import PyBC_opt_dh
import numpy as np
import matplotlib.pyplot as plt
#%pylab notebook
# %pylab inline   
from writeit import *
import pickle
import time

def idx_t(i,j,n,N):
    return (2*(N+2)*n+(N+2)*i+j)

# Define a function to get time average to suppress oscillation
# P is the pressure that should be averaged over time
# Mi is how many time steps you want to average 
# dt is the initital time step size
def t_average(P, Mi, dt):
    if Mi == 1:
        return np.linspace(0,n1.T, n1.M+1),P
    n = int(len(P[:-1])/Mi)    # Totally M steps in P{:-1], n=M/Mi, n should be an integer
    x = []          
    P_new = []
    for i in xrange(n):
        P_new.append(np.average(P[i*Mi:(i+1)*Mi-1]))
        x.append((i+0.5)*Mi*dt)
    return x, P_new

#specify input files
fi = "/home/xin/pipes/indata/Xindata/Tpipe_two_side.inp"    
mtype = 1 

# Template for writing files
fc = "/home/xin/pipes/indata/Xindata/Tpipe_two_side.config"
with open (fc,"r+") as fread:
    cont = fread.readlines()


# Specify inflow velocities
# v_ins = [0.5, 1., 1.5, 2.5, 3.]
v_ins = [2.]


"""ctrl + ]  means indent"""
t_start = time.time()

for v_in in v_ins:
    for branch_flow_ratio in np.arange(0.1,1,0.1):
        #------------------------------------------------------------
        # start to build network and run model
        #----------------------------------------------------------------
        n1 = PyNetwork(fi,fc,mtype) 
        M = n1.M  
        T = n1.T  

        # Set BC
        # Inflow from pipe 0
        q0 = (1-branch_flow_ratio)*v_in*n1.Ds[0]**2*np.pi/4. 
        Q0 = q0*np.ones(M+1)
        n1.setbVal(0,Q0)

        # Inflow from pipe 2
        q2 = branch_flow_ratio*v_in*n1.Ds[0]**2*np.pi/4.        
        Q2 = -q2*np.ones(M+1)     
        n1.setbVal(2,Q2)

        # Set IC
        for i in xrange(3):
            A00 = n1.Ds[i]**2*np.pi/4.*np.ones(n1.Ns[i])         # make the IC full
            Q00 = 1e-8*A00    # make the initial v0 = 1e-4
            n1.setIC(i,A00,Q00)


        # Print Some Information
        p1 = PyPipe_ps(n1.Ns[0], n1.Ds[0],n1.Ls[0], M, n1.a[0])
        p_head = p1.pbar(0.25*0.25*3.14,True)
        print "When the pipe is full, the average hydrostatic pressure head is", p_head, "m"
        print "the slot width in pipe 2 is:",9.81*(n1.Ds[2]**2*np.pi/4.)/(n1.a[0]**2)


        # Run simulation
        dt = T/float(M)#time step
        V0 = n1.getTotalVolume()
        n1.runForwardProblem(dt)

        #----------------------------------------------------------------------------
        # Calculate Pressure Head Difference 
        #----------------------------------------------------------------------------

        P0 = n1.pressureTimeSeries(0,n1.Ns[0]-1) 
        P1 = n1.pressureTimeSeries(1,0)
        P2 = n1.pressureTimeSeries(2,0)
        t = np.linspace(0,n1.T, n1.M+1)

        Mi = 1
        fig = plt.figure(figsize= (10,5))
        x0, P0 = t_average(P0, Mi, dt)
        x1, P1 = t_average(P1, Mi, dt)
        x2, P2 = t_average(P2, Mi, dt)
        plt.plot(x0,P0,label = 'P0')
        plt.plot(x1,P1, label = 'P1')
        plt.plot(x2,P2, label = 'P2')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("Pressue Head (m)")
        plt.show()
        time.sleep(1)

        #----------------------------------------------------------------------------
        # Calculate Q1, Q2 distribution
        #----------------------------------------------------------------------------
        # get pipe (A,Q)data
        qh0 = n1.qhist(0)
        qh1 = n1.qhist(1)
        qh2 = n1.qhist(2)
        N = n1.Ns[1]

        Qext0 = [qh0[idx_t(1,0,it,n1.Ns[0])] for it in xrange(n1.M+1)]
        Qext1 = [qh1[idx_t(1,N+1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
        Qext2 = [qh2[idx_t(1,N+1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
        x3, Qext0 = t_average(Qext0, Mi, dt)
        x4, Qext1 = t_average(Qext1, Mi, dt)
        x5, Qext2 = t_average(Qext2, Mi, dt)

        #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
        #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
        fig = plt.figure(figsize= (10,5))
        plt.plot(x3,Qext0, label = 'Pipe 0 outflow')
        plt.plot(x4,Qext1, label = 'Pipe 1 outflow')
        plt.plot(x5,Qext2, label = 'Pipe 2 outflow')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("flux(m^3/s)")
        #plt.ylim(0, 0.3)
        plt.show()
        time.sleep(1)
        
        
        Aext0 = [qh0[idx_t(0,N,it,n1.Ns[0])] for it in xrange(n1.M+1)]
        Aext1 = [qh1[idx_t(0,1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
        Aext2 = [qh2[idx_t(0,1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
        H0_bottom = [p1.HofA(i,True) for i in Aext0]
        H1_bottom = [p1.HofA(i,True) for i in Aext1]
        H2_bottom = [p1.HofA(i,True) for i in Aext2]
        x6, H0_bottom = t_average(H0_bottom, Mi, dt)
        x7, H1_bottom = t_average(H1_bottom, Mi, dt)
        x8, H2_bottom = t_average(H2_bottom, Mi, dt)

        #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
        #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
        fig = plt.figure(figsize= (10,5))
        plt.plot(x6,H0_bottom, label = 'Pipe 0 watre depth')
        plt.plot(x7,H1_bottom, label = 'Pipe 1 water depth')
        plt.plot(x8,H2_bottom, label = 'Pipe 2 water depth')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("Water Depth(m)")
        #plt.ylim(0, 0.3)
        plt.show()
        time.sleep(1)



#         ### Plot Q values for all pipes in a certain time slice
#         track = 1
#         t_interest = 0.723#n1.T-(track-1)*dt
#         M_interest = int((t_interest/n1.T*(n1.M)))    
#         Q_pipe0 = [qh0[idx_t(1,i,M_interest,n1.Ns[0])] for i in xrange(1,n1.Ns[0]+1)]   # 0 and N+1 are ghost grid values
#         Q_pipe1 = [qh1[idx_t(1,i,M_interest,n1.Ns[1])] for i in xrange(1,n1.Ns[1]+1)]  
#         Q_pipe2 = [qh2[idx_t(1,i,M_interest,n1.Ns[2])] for i in xrange(1,n1.Ns[2]+1)]
#         x_Qpipe = []
#         for i in xrange(len(n1.Ls)):
#             x_Qpipe.append( np.linspace(0,n1.Ls[i],n1.Ns[i]) )

        #--------------------------------------------------------------------
        # Print Information
        #---------------------------------------------------------------------


        print "Now the delta t is ", Mi*dt

        mdx = min([n1.Ls[i]/n1.Ns[i] for i in range(n1.Nedges)])
        print mdx, dt
        print n1.cmax
        print "CFL = 1/(dx/dt)*(max wave speed) = %f" % (max(n1.cmax)*dt/mdx)    

        print "Pressure Head in Pipe 0 is: ",P0[-1], "m","bottom head is:",H0_bottom[-1]
        print "Pressure Head in Pipe 1 is: ",P1[-1], "m","bottom head is:",H1_bottom[-1]
        print "Pressure Head in Pipe 2 is: ",P2[-1], "m","bottom head is:",H2_bottom[-1]

        print "v in Pipe 1 is: ",Qext1[-1]/(n1.Ds[1]**2*np.pi/4. ), "m/s"
        print "v in Pipe 2 is: ",Qext2[-1]/(n1.Ds[2]**2*np.pi/4. ), "m/s"
        
        # Check for Dividing Flow
        alpha = 1.
        v0 = Qext0[-1]/(n1.Ds[0]**2*np.pi/4.)
        v1 = Qext1[-1]/(n1.Ds[1]**2*np.pi/4. )
        v2 = Qext2[-1]/(n1.Ds[2]**2*np.pi/4. )
        TH0 = P0[-1]  + (v0)**2/2/9.81*alpha
        TH1 = P1[-1]  + (v1)**2/2/9.81*alpha
        TH2 = P2[-1]  + (v2)**2/2/9.81*alpha
        print "Total Head in Pipe 0 is: ",TH0, "m"
        print "Total Head in Pipe 1 is: ",TH1, "m"
        print "Total Head in Pipe 2 is: ",TH2, "m"

        # 0,2 -> 1
        print "K0-1(main) =", (TH0-TH1)/(v1**2/2/9.81)
        print "K2-1(branch) =", (TH2-TH1)/(v1**2/2/9.81)

        print "Branch flow ratio =", branch_flow_ratio
        print "Re =", abs(v1)*n1.Ds[0]/(1.14*1e-6)

        # Make model relax and ready for next round
        n1.reset()
        time.sleep(2)
    
t_end = time.time()
print "The total time is ", t_end-t_start, " s"

# Make sound to remind me that the code has be finished
import subprocess
subprocess.call(['speech-dispatcher'])        #start speech dispatcher
subprocess.call(['spd-say', '"barbar, your process has finished"'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.71712122799235, 297.7787170109052, 210.717095992851]
# CFL = 1/(dx/dt)*(max wave speed) = 0.496298
# Pressure Head in Pipe 0 is:  12.428080867 m bottom head is: 12.6155803289
# Pressure Head in Pipe 1 is:  12.3753198531 m bottom head is: 12.5624991787
# Pressure Head in Pipe 2 is:  12.4258994589 m bottom head is: 12.6133856575
# v in Pipe 1 is:  2.00071431979 m/s
# v in Pipe 2 is:  -0.2 m/s
# Total Head in Pipe 0 is:  12.5932184816 m
# Total Head in Pipe 1 is:  12.5793391084 m
# Total Head in Pipe 2 is:  12.4279381949 m
# K0-1(main) = 0.0680297221096
# K2-1(branch) = -0.742091295518
# Branch flow ratio = 0.1
# Re = 526503.768365
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.7131448737542, 297.55528350389034, 210.71313156628258]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495925
# Pressure Head in Pipe 0 is:  12.4004988689 m bottom head is: 12.5878308007
# Pressure Head in Pipe 1 is:  12.2913572309 m bottom head is: 12.4780299374
# Pressure Head in Pipe 2 is:  12.4608635725 m bottom head is: 12.6485626424
# v in Pipe 1 is:  2.00004849835 m/s
# v in Pipe 2 is:  -0.4 m/s
# Total Head in Pipe 0 is:  12.5309779718 m
# Total Head in Pipe 1 is:  12.4952407169 m
# Total Head in Pipe 2 is:  12.4690185165 m
# K0-1(main) = 0.175282734536
# K2-1(branch) = -0.128613655411
# Branch flow ratio = 0.2
# Re = 526328.552198
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.7131119826943, 297.55401005834136, 210.71311229823235]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495923
# Pressure Head in Pipe 0 is:  12.4463050525 m bottom head is: 12.6339154126
# Pressure Head in Pipe 1 is:  12.2912269966 m bottom head is: 12.4778989199
# Pressure Head in Pipe 2 is:  12.477940139 m bottom head is: 12.6657433954
# v in Pipe 1 is:  2.00005897663 m/s
# v in Pipe 2 is:  -0.6 m/s
# Total Head in Pipe 0 is:  12.5462031158 m
# Total Head in Pipe 1 is:  12.4951126189 m
# Total Head in Pipe 2 is:  12.4962887628 m
# K0-1(main) = 0.250584108352
# K2-1(branch) = 0.00576864583733
# Branch flow ratio = 0.3
# Re = 526331.309639
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.7131158112051, 297.55435082329547, 210.71311986981084]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495924
# Pressure Head in Pipe 0 is:  12.48677631 m bottom head is: 12.6746335339
# Pressure Head in Pipe 1 is:  12.2918460066 m bottom head is: 12.4785216522
# Pressure Head in Pipe 2 is:  12.5008506965 m bottom head is: 12.6887939601
# v in Pipe 1 is:  2.00006715338 m/s
# v in Pipe 2 is:  -0.8 m/s
# Total Head in Pipe 0 is:  12.5601708055 m
# Total Head in Pipe 1 is:  12.495733296 m
# Total Head in Pipe 2 is:  12.5334704722 m
# K0-1(main) = 0.316044760203
# K2-1(branch) = 0.185088419963
# Branch flow ratio = 0.4
# Re = 526333.461416
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.7131224299318, 297.5547425360559, 210.71312402297147]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495925
# Pressure Head in Pipe 0 is:  12.5212335615 m bottom head is: 12.7093016036
# Pressure Head in Pipe 1 is:  12.2924547489 m bottom head is: 12.4791340552
# Pressure Head in Pipe 2 is:  12.5226482219 m bottom head is: 12.7107249318
# v in Pipe 1 is:  2.00007310052 m/s
# v in Pipe 2 is:  -1.0 m/s
# Total Head in Pipe 0 is:  12.572201961 m
# Total Head in Pipe 1 is:  12.4963432508 m
# Total Head in Pipe 2 is:  12.5736166215 m
# K0-1(main) = 0.37205977534
# K2-1(branch) = 0.378998177629
# Branch flow ratio = 0.5
# Re = 526335.026453
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.71312854020562, 297.5550152252568, 210.71312740252748]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495925
# Pressure Head in Pipe 0 is:  12.5495873575 m bottom head is: 12.7378293157
# Pressure Head in Pipe 1 is:  12.2929522616 m bottom head is: 12.4796345598
# Pressure Head in Pipe 2 is:  12.5408661756 m bottom head is: 12.7290545976
# v in Pipe 1 is:  2.00007693562 m/s
# v in Pipe 2 is:  -1.2 m/s
# Total Head in Pipe 0 is:  12.5822071332 m
# Total Head in Pipe 1 is:  12.4968415454 m
# Total Head in Pipe 2 is:  12.614260671 m
# K0-1(main) = 0.418685995722
# K2-1(branch) = 0.575896503237
# Branch flow ratio = 0.6
# Re = 526336.035689
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.71313376016636, 297.55514743565806, 210.71313010170388]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495925
# Pressure Head in Pipe 0 is:  12.571815651 m bottom head is: 12.7601942309
# Pressure Head in Pipe 1 is:  12.2933175933 m bottom head is: 12.4800020886
# Pressure Head in Pipe 2 is:  12.5544252101 m bottom head is: 12.7426968824
# v in Pipe 1 is:  2.00007871625 m/s
# v in Pipe 2 is:  -1.4 m/s
# Total Head in Pipe 0 is:  12.5901642749 m
# Total Head in Pipe 1 is:  12.4972072402 m
# Total Head in Pipe 2 is:  12.6543232733 m
# K0-1(main) = 0.455918366314
# K2-1(branch) = 0.770593482935
# Branch flow ratio = 0.7
# Re = 526336.504276
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.71313614016557, 297.5550605254726, 210.71313392714143]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495925
# Pressure Head in Pipe 0 is:  12.5878729787 m bottom head is: 12.7763504037
# Pressure Head in Pipe 1 is:  12.2935109319 m bottom head is: 12.48019659
# Pressure Head in Pipe 2 is:  12.5628202212 m bottom head is: 12.751143483
# v in Pipe 1 is:  2.0000796364 m/s
# v in Pipe 2 is:  -1.6 m/s
# Total Head in Pipe 0 is:  12.5960279227 m
# Total Head in Pipe 1 is:  12.4974007663 m
# Total Head in Pipe 2 is:  12.6932993241 m
# K0-1(main) = 0.483727678739
# K2-1(branch) = 0.960805909292
# Branch flow ratio = 0.8
# Re = 526336.74642
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 1.73357009616e-05
# Now the delta t is  5e-05
# 0.03 5e-05
# [210.7131392397782, 297.5549478444428, 210.7131351865306]
# CFL = 1/(dx/dt)*(max wave speed) = 0.495925
# Pressure Head in Pipe 0 is:  12.597835878 m bottom head is: 12.7863746963
# Pressure Head in Pipe 1 is:  12.2936144128 m bottom head is: 12.4803006932
# Pressure Head in Pipe 2 is:  12.565695275 m bottom head is: 12.7540362129
# v in Pipe 1 is:  2.00008108498 m/s
# v in Pipe 2 is:  -1.8 m/s
# Total Head in Pipe 0 is:  12.599874614 m
# Total Head in Pipe 1 is:  12.4975045426 m
# Total Head in Pipe 2 is:  12.7308328897 m
# K0-1(main) = 0.502084487993
# K2-1(branch) = 1.14438274861
# Branch flow ratio = 0.9
# Re = 526337.127626
# The total time is  695.789518118  s
# 0

# %%
oris = np.arange(0.01, 0.11, 0.01)
for ori in oris:
    Atao = p1.AofH(0.83*ori,True)
    Q = 0.3**2*np.pi/4.*1.
    H = (Q/0.78/Atao)**2/2/9.81+0.83*ori
    print ori, H
