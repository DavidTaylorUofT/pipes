# %% [markdown]
# <p> Run a simulation of filling in a network based on the 7 de Septiembre neighborhood layout in Araijan </p>
# <p>**(.inp and .config files already written)**</p>
# <p> Below you see how to:</p>
# <ul>
# <li>Set boundary and initial conditions </li>
# <li>Run a simulation until time T= 1200 s</li>
# <li>plot time series of pressure head at different points in a single pipe</li>
# <li>plot time series of pressure head at sample points in various pipes</li>
# <li>plot space dependence of pressure head at a certain time</li>
# <li>look at velocities</li>
# <li>plot network layout</li>
# </ul>

# %%
from __future__ import division
import sys
sys.path.append("/home/xin/pipes")   
from allthethings import PyNetwork, PyPipe_ps
from allthethings import PyBC_opt_dh
import numpy as np
import matplotlib.pyplot as plt
#%pylab notebook
# %pylab inline   
from writeit import *
import pickle
import time

def idx_t(i,j,n,N):
    return (2*(N+2)*n+(N+2)*i+j)

# Define a function to get time average to suppress oscillation
# P is the pressure that should be averaged over time
# Mi is how many time steps you want to average 
# dt is the initital time step size
def t_average(P, Mi, dt):
    if Mi == 1:
        return np.linspace(0,n1.T, n1.M+1),P
    n = int(len(P[:-1])/Mi)    # Totally M steps in P{:-1], n=M/Mi, n should be an integer
    x = []          
    P_new = []
    for i in xrange(n):
        P_new.append(np.average(P[i*Mi:(i+1)*Mi-1]))
        x.append((i+0.5)*Mi*dt)
    return x, P_new

#specify input files
fi = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_difsize.inp"    
mtype = 1 

# Template for writing files
fc = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_another.config"
with open (fc,"r+") as fread:
    cont = fread.readlines()


# Specify inflow velocities
# v_ins = [0.5, 1., 1.5, 2.5, 3.]
v_ins = [2.]


# Specify different openings for two orifices: [R1, R2, RunningTime]
orifice_info_set = [
      [0.02, 0.1, 0.5],
      [0.06, 0.09, 0.5],
      [0.06, 0.10, 0.5],
      [0.06, 0.06, 0.5],
      [0.09, 0.06, 0.5],
      [0.09, 0.03, 0.5],
      [0.1, 0.05, 0.5],
      [0.1, 0.08, 0.5],
      [0.04, 0.1, 0.5],
      [0.02, 0.06, 0.5],
      [0.03, 0.06, 0.5],
      [0.1, 0.02, 0.5],
      [0.02, 0.14, 0.5],
]


"""ctrl + ]  means indent"""
t_start = time.time()

for v_in in v_ins:
    for orifice_info in orifice_info_set:

        #------------------------------------------------------------
        # Uisng information to create input files
        #--------------------------------------------------------------
        fc_series = "/home/xin/pipes/indata/Xindata/Tpipe_two_side_another_series.config"
        with open (fc_series,"w") as fwrite:
            for i in xrange(len(cont)):
                if i == 16:
                    r1_line = cont[i].split()
                    r1_line[3] = str(orifice_info[0])
                    r1_line = "        ".join(r1_line)
                    fwrite.write(" "+r1_line)
                    fwrite.write("\n")
                elif i== 17:
                    r2_line = cont[i].split()
                    r2_line[3] = str(orifice_info[1])
                    r2_line = "        ".join(r2_line)
                    fwrite.write(" "+r2_line)  
                    fwrite.write("\n")
                elif i == 21:
                    time_line = cont[i].split()
                    time_line[0] = str(orifice_info[2])
                    time_line[1] = str(int(orifice_info[2]*20000))
                    time_line = "         ".join(time_line)
                    fwrite.write(time_line)   
                else:
                    fwrite.write(cont[i])

        #------------------------------------------------------------
        # start to build network and run model
        #----------------------------------------------------------------
        n1 = PyNetwork(fi,fc_series,mtype) 
        M = n1.M  
        T = n1.T  

        # Set BC
        q0 = v_in*n1.Ds[0]**2*np.pi/4.        # inflow = 1m/s, used to create the Q0 vector
        Q0 = q0*np.ones(M+1)     
        n1.setbVal(0,Q0)

        # Set IC
        for i in xrange(3):
            A00 = n1.Ds[i]**2*np.pi/4.*np.ones(n1.Ns[i])         # make the IC full
            Q00 = 1e-8*A00    # make the initial v0 = 1e-4
           
            n1.setIC(i,A00,Q00)


        # Print Some Information
        p1 = PyPipe_ps(n1.Ns[0], n1.Ds[0],n1.Ls[0], M, n1.a[0])
        p2 = PyPipe_ps(n1.Ns[2], n1.Ds[2],n1.Ls[2], M, n1.a[0])
        p_head = p1.pbar(0.25*0.25*3.14,True)
        print "When the pipe is full, the average hydrostatic pressure head is", p_head, "m"
        print "the slot width in pipe 2 is:",9.81*(n1.Ds[2]**2*np.pi/4.)/(n1.a[0]**2)


        # Run simulation
        dt = T/float(M)#time step
        V0 = n1.getTotalVolume()
        n1.runForwardProblem(dt)

        #----------------------------------------------------------------------------
        # Calculate Pressure Head Difference 
        #----------------------------------------------------------------------------

        P0 = n1.pressureTimeSeries(0,n1.Ns[0]-1) 
        P1 = n1.pressureTimeSeries(1,0)
        P2 = n1.pressureTimeSeries(2,0)
        t = np.linspace(0,n1.T, n1.M+1)

        Mi = 1
        fig = plt.figure(figsize= (10,5))
        x0, P0 = t_average(P0, Mi, dt)
        x1, P1 = t_average(P1, Mi, dt)
        x2, P2 = t_average(P2, Mi, dt)
        plt.plot(x0,P0,label = 'P0')
        plt.plot(x1,P1, label = 'P1')
        plt.plot(x2,P2, label = 'P2')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("Pressue Head (m)")
        plt.show()
        time.sleep(1)

        #----------------------------------------------------------------------------
        # Calculate Q1, Q2 distribution
        #----------------------------------------------------------------------------
        # get pipe (A,Q)data
        qh0 = n1.qhist(0)
        qh1 = n1.qhist(1)
        qh2 = n1.qhist(2)
        N = n1.Ns[1]

        Qext0 = [qh0[idx_t(1,0,it,n1.Ns[0])] for it in xrange(n1.M+1)]
        Qext1 = [qh1[idx_t(1,N+1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
        Qext2 = [qh2[idx_t(1,N+1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
        x3, Qext0 = t_average(Qext0, Mi, dt)
        x4, Qext1 = t_average(Qext1, Mi, dt)
        x5, Qext2 = t_average(Qext2, Mi, dt)

        #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
        #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
        fig = plt.figure(figsize= (10,5))
        plt.plot(x3,Qext0, label = 'Pipe 0 outflow')
        plt.plot(x4,Qext1, label = 'Pipe 1 outflow')
        plt.plot(x5,Qext2, label = 'Pipe 2 outflow')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("flux(m^3/s)")
        #plt.ylim(0, 0.3)
        plt.show()
        time.sleep(1)
        
        
        Aext0 = [qh0[idx_t(0,N,it,n1.Ns[0])] for it in xrange(n1.M+1)]
        Aext1 = [qh1[idx_t(0,1,it,n1.Ns[1])] for it in xrange(n1.M+1)]
        Aext2 = [qh2[idx_t(0,1,it,n1.Ns[2])] for it in xrange(n1.M+1)]
        H0_bottom = [p1.HofA(i,True) for i in Aext0]
        H1_bottom = [p1.HofA(i,True) for i in Aext1]
        H2_bottom = [p2.HofA(i,True) for i in Aext2]
        x6, H0_bottom = t_average(H0_bottom, Mi, dt)
        x7, H1_bottom = t_average(H1_bottom, Mi, dt)
        x8, H2_bottom = t_average(H2_bottom, Mi, dt)

        #print "Q1 finally =",Qext1[-1], "Percentage =", Qext1[-1]/q0
        #print "Q2 finally =",Qext2[-1],"Percentage =", Qext2[-1]/q0
        fig = plt.figure(figsize= (10,5))
        plt.plot(x6,H0_bottom, label = 'Pipe 0 watre depth')
        plt.plot(x7,H1_bottom, label = 'Pipe 1 water depth')
        plt.plot(x8,H2_bottom, label = 'Pipe 2 water depth')
        plt.legend(loc='best')
        plt.xlabel("time")
        plt.ylabel("Water Depth(m)")
        #plt.ylim(0, 0.3)
        plt.show()
        time.sleep(1)



#         ### Plot Q values for all pipes in a certain time slice
#         track = 1
#         t_interest = 0.723#n1.T-(track-1)*dt
#         M_interest = int((t_interest/n1.T*(n1.M)))    
#         Q_pipe0 = [qh0[idx_t(1,i,M_interest,n1.Ns[0])] for i in xrange(1,n1.Ns[0]+1)]   # 0 and N+1 are ghost grid values
#         Q_pipe1 = [qh1[idx_t(1,i,M_interest,n1.Ns[1])] for i in xrange(1,n1.Ns[1]+1)]  
#         Q_pipe2 = [qh2[idx_t(1,i,M_interest,n1.Ns[2])] for i in xrange(1,n1.Ns[2]+1)]
#         x_Qpipe = []
#         for i in xrange(len(n1.Ls)):
#             x_Qpipe.append( np.linspace(0,n1.Ls[i],n1.Ns[i]) )

        #--------------------------------------------------------------------
        # Print Information
        #---------------------------------------------------------------------
        print "The current orifice inforamtion is ",orifice_info


        print "Now the delta t is ", Mi*dt

        mdx = min([n1.Ls[i]/n1.Ns[i] for i in range(n1.Nedges)])
        print mdx, dt
        print n1.cmax
        print "CFL = 1/(dx/dt)*(max wave speed) = %f" % (max(n1.cmax)*dt/mdx)    

        print "Pressure Head in Pipe 0 is: ",P0[-1], "m","bottom head is:",H0_bottom[-1]
        print "Pressure Head in Pipe 1 is: ",P1[-1], "m","bottom head is:",H1_bottom[-1]
        print "Pressure Head in Pipe 2 is: ",P2[-1], "m","bottom head is:",H2_bottom[-1]

        print "v in Pipe 1 is: ",Qext1[-1]/(n1.Ds[1]**2*np.pi/4. ), "m/s"
        print "v in Pipe 2 is: ",Qext2[-1]/(n1.Ds[2]**2*np.pi/4. ), "m/s"
        
       

        # Check for Dividing Flow
        alpha = 1.
        v0 = Qext0[-1]/(n1.Ds[0]**2*np.pi/4.)
        v1 = Qext1[-1]/(n1.Ds[1]**2*np.pi/4. )
        v2 = Qext2[-1]/(n1.Ds[2]**2*np.pi/4. )
        TH0 = P0[-1]  + (v0)**2/2/9.81*alpha
        TH1 = P1[-1]  + (v1)**2/2/9.81*alpha
        TH2 = P2[-1]  + (v2)**2/2/9.81*alpha
        print "Total Head in Pipe 0 is: ",TH0, "m"
        print "Total Head in Pipe 1 is: ",TH1, "m"
        print "Total Head in Pipe 2 is: ",TH2, "m"

        print "K0-1 =", (TH0-TH1)/(v0**2/2/9.81)
        print "K0-2 =", (TH0-TH2)/(v0**2/2/9.81)

        print "Branch flow ratio =", Qext2[-1]/q0
        print "Re =", v0*n1.Ds[0]/(1.14*1e-6)

        # Make model relax and ready for next round
        n1.reset()
        time.sleep(2)
    
t_end = time.time()
print "The total time is ", t_end-t_start, " s"

# Make sound to remind me that the code has be finished
import subprocess
subprocess.call(['speech-dispatcher'])        #start speech dispatcher
subprocess.call(['spd-say', '"barbar, your process has finished"'])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.02, 0.1, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.99567076729608, 200.22956962103908, 203.6051326825737]
# CFL = 1/(dx/dt)*(max wave speed) = 0.339342
# Pressure Head in Pipe 0 is:  9.08655633653 m bottom head is: 9.25649534291
# Pressure Head in Pipe 1 is:  9.24628383775 m bottom head is: 9.41693679516
# Pressure Head in Pipe 2 is:  8.13881806384 m bottom head is: 8.25986958772
# v in Pipe 1 is:  0.230008824664 m/s
# v in Pipe 2 is:  3.61225344684 m/s
# Total Head in Pipe 0 is:  9.2904299349 m
# Total Head in Pipe 1 is:  9.24898027299 m
# Total Head in Pipe 2 is:  8.80387285304 m
# K0-1 = 0.203310591645
# K0-2 = 2.38656248651
# Branch flow ratio = 0.885002094476
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.06, 0.09, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.9976687783216, 200.8527656410649, 202.3366831803875]
# CFL = 1/(dx/dt)*(max wave speed) = 0.337228
# Pressure Head in Pipe 0 is:  4.89205886973 m bottom head is: 5.04774930566
# Pressure Head in Pipe 1 is:  5.04939622755 m bottom head is: 5.20546478822
# Pressure Head in Pipe 2 is:  4.51093670493 m bottom head is: 4.62081144328
# v in Pipe 1 is:  0.853792707734 m/s
# v in Pipe 2 is:  2.3392228521 m/s
# Total Head in Pipe 0 is:  5.0959324681 m
# Total Head in Pipe 1 is:  5.08655025343 m
# Total Head in Pipe 2 is:  4.78983392979 m
# K0-1 = 0.0460197629269
# K0-2 = 1.50141333038
# Branch flow ratio = 0.573109598765
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.06, 0.1, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.9980094123997, 200.7934243762046, 202.45852737267361]
# CFL = 1/(dx/dt)*(max wave speed) = 0.337431
# Pressure Head in Pipe 0 is:  4.19668320821 m bottom head is: 4.35084823927
# Pressure Head in Pipe 1 is:  4.35688696368 m bottom head is: 4.51138235032
# Pressure Head in Pipe 2 is:  3.76921366382 m bottom head is: 3.87760053648
# v in Pipe 1 is:  0.794244943294 m/s
# v in Pipe 2 is:  2.46075153062 m/s
# Total Head in Pipe 0 is:  4.40055680658 m
# Total Head in Pipe 1 is:  4.38903910588 m
# Total Head in Pipe 2 is:  4.07784251679 m
# K0-1 = 0.0564943218936
# K0-2 = 1.58291359137
# Branch flow ratio = 0.602884125002
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.06, 0.06, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.99590054870995, 201.11043944212616, 201.8070673605661]
# CFL = 1/(dx/dt)*(max wave speed) = 0.336660
# Pressure Head in Pipe 0 is:  8.50061125194 m bottom head is: 8.66803894621
# Pressure Head in Pipe 1 is:  8.63929783109 m bottom head is: 8.80730463
# Pressure Head in Pipe 2 is:  8.29911115355 m bottom head is: 8.42080603958
# v in Pipe 1 is:  1.11275733142 m/s
# v in Pipe 2 is:  1.81071376616 m/s
# Total Head in Pipe 0 is:  8.70448485031 m
# Total Head in Pipe 1 is:  8.70240837536 m
# Total Head in Pipe 2 is:  8.46622044728 m
# K0-1 = 0.010185109623
# K0-2 = 1.16868689687
# Branch flow ratio = 0.44362487271
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.09, 0.06, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.9980702835762, 201.38068756837896, 201.25987211989175]
# CFL = 1/(dx/dt)*(max wave speed) = 0.336663
# Pressure Head in Pipe 0 is:  4.05667451215 m bottom head is: 4.21056116123
# Pressure Head in Pipe 1 is:  4.16611729929 m bottom head is: 4.32022073352
# Pressure Head in Pipe 2 is:  4.00116812631 m bottom head is: 4.10999123386
# v in Pipe 1 is:  1.38205216535 m/s
# v in Pipe 2 is:  1.26108251909 m/s
# Total Head in Pipe 0 is:  4.26054811052 m
# Total Head in Pipe 1 is:  4.26347041793 m
# Total Head in Pipe 2 is:  4.08222465638 m
# K0-1 = -0.0143339178655
# K0-2 = 0.874676542559
# Branch flow ratio = 0.308965217177
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.09, 0.03, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.99694416428989, 201.70926158635964, 200.58705512332344]
# CFL = 1/(dx/dt)*(max wave speed) = 0.336662
# Pressure Head in Pipe 0 is:  6.37085209003 m bottom head is: 6.53057714095
# Pressure Head in Pipe 1 is:  6.42895613792 m bottom head is: 6.58886168782
# Pressure Head in Pipe 2 is:  6.41025553591 m bottom head is: 6.52517359565
# v in Pipe 1 is:  1.71190166442 m/s
# v in Pipe 2 is:  0.587965221429 m/s
# Total Head in Pipe 0 is:  6.5747256884 m
# Total Head in Pipe 1 is:  6.57832450227 m
# Total Head in Pipe 2 is:  6.42787546973 m
# K0-1 = -0.0176521820486
# K0-2 = 0.720300322543
# Branch flow ratio = 0.14405147925
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.1, 0.05, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.998220363246, 201.53583434776306, 200.9435747072095]
# CFL = 1/(dx/dt)*(max wave speed) = 0.336664
# Pressure Head in Pipe 0 is:  3.75096416629 m bottom head is: 3.90427644668
# Pressure Head in Pipe 1 is:  3.83836896519 m bottom head is: 3.99184077371
# Pressure Head in Pipe 2 is:  3.75659616144 m bottom head is: 3.86496006264
# v in Pipe 1 is:  1.53722890781 m/s
# v in Pipe 2 is:  0.944423631079 m/s
# Total Head in Pipe 0 is:  3.95483776466 m
# Total Head in Pipe 1 is:  3.95881099959 m
# Total Head in Pipe 2 is:  3.80205671165 m
# K0-1 = -0.0194887173426
# K0-2 = 0.749391065027
# Branch flow ratio = 0.231383789614
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.1, 0.08, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.99879151822407, 201.28010577612093, 201.4647467174922]
# CFL = 1/(dx/dt)*(max wave speed) = 0.336665
# Pressure Head in Pipe 0 is:  2.52649403347 m bottom head is: 2.6779659731
# Pressure Head in Pipe 1 is:  2.64823113919 m bottom head is: 2.79985308544
# Pressure Head in Pipe 2 is:  2.42142421932 m bottom head is: 2.52779925126
# v in Pipe 1 is:  1.28038401638 m/s
# v in Pipe 2 is:  1.46508794996 m/s
# Total Head in Pipe 0 is:  2.73036763184 m
# Total Head in Pipe 1 is:  2.73178787871 m
# Total Head in Pipe 2 is:  2.53082700735 m
# K0-1 = -0.00696631089185
# K0-2 = 0.978746763107
# Branch flow ratio = 0.358946547739
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.04, 0.1, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.99700888012023, 200.5320150649635, 202.99022430305806]
# CFL = 1/(dx/dt)*(max wave speed) = 0.338317
# Pressure Head in Pipe 0 is:  6.23879837984 m bottom head is: 6.3981193895
# Pressure Head in Pipe 1 is:  6.40471257136 m bottom head is: 6.56454260708
# Pressure Head in Pipe 2 is:  5.58883555981 m bottom head is: 5.70135467799
# v in Pipe 1 is:  0.532832539078 m/s
# v in Pipe 2 is:  2.99426259606 m/s
# Total Head in Pipe 0 is:  6.44267197821 m
# Total Head in Pipe 1 is:  6.41918303592 m
# Total Head in Pipe 2 is:  6.04579827613 m
# K0-1 = 0.115213261926
# K0-2 = 1.94666550872
# Branch flow ratio = 0.733594336034
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.02, 0.06, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.98981877123686, 200.39951202614705, 203.24618724279082]
# CFL = 1/(dx/dt)*(max wave speed) = 0.338744
# Pressure Head in Pipe 0 is:  27.791279343 m bottom head is: 28.1307752913
# Pressure Head in Pipe 1 is:  27.9554507758 m bottom head is: 28.297206032
# Pressure Head in Pipe 2 is:  27.0287414812 m bottom head is: 27.3132201341
# v in Pipe 1 is:  0.399175876442 m/s
# v in Pipe 2 is:  3.26771700556 m/s
# Total Head in Pipe 0 is:  27.9951529413 m
# Total Head in Pipe 1 is:  27.9635721509 m
# Total Head in Pipe 2 is:  27.5729807487 m
# K0-1 = 0.154903776967
# K0-2 = 2.07075460496
# Branch flow ratio = 0.800590666363
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.03, 0.06, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.99002716121802, 200.62168144990758, 202.79287975257552]
# CFL = 1/(dx/dt)*(max wave speed) = 0.337988
# Pressure Head in Pipe 0 is:  20.5189473911 m bottom head is: 20.7718623524
# Pressure Head in Pipe 1 is:  20.6822089558 m bottom head is: 20.9367784258
# Pressure Head in Pipe 2 is:  19.9576427495 m bottom head is: 20.160191655
# v in Pipe 1 is:  0.62481267078 m/s
# v in Pipe 2 is:  2.8065464288 m/s
# Total Head in Pipe 0 is:  20.7228209894 m
# Total Head in Pipe 1 is:  20.7021065538 m
# Total Head in Pipe 2 is:  20.3591056882 m
# K0-1 = 0.101604306701
# K0-2 = 1.78402355246
# Branch flow ratio = 0.687603875055
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.1, 0.02, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.9973378607337, 201.84940238955517, 200.30188947338758]
# CFL = 1/(dx/dt)*(max wave speed) = 0.336662
# Pressure Head in Pipe 0 is:  5.56749508965 m bottom head is: 5.72489484312
# Pressure Head in Pipe 1 is:  5.59895701783 m bottom head is: 5.75644186178
# Pressure Head in Pipe 2 is:  5.55672528088 m bottom head is: 5.66915736513
# v in Pipe 1 is:  1.85188189402 m/s
# v in Pipe 2 is:  0.302293761907 m/s
# Total Head in Pipe 0 is:  5.77136868802 m
# Total Head in Pipe 1 is:  5.77375143931 m
# Total Head in Pipe 2 is:  5.56138285063 m
# K0-1 = -0.0116873950673
# K0-2 = 1.0299805324
# Branch flow ratio = 0.0740619716671
# Re = 526315.789474
# When the pipe is full, the average hydrostatic pressure head is 2611.55363055 m
# the slot width in pipe 2 is: 8.49449347118e-06
# The current orifice inforamtion is  [0.02, 0.14, 0.5]
# Now the delta t is  5e-05
# 0.03 5e-05
# [201.9977335110091, 200.16825135584554, 203.73454775440268]
# CFL = 1/(dx/dt)*(max wave speed) = 0.339558
# Pressure Head in Pipe 0 is:  4.74358283921 m bottom head is: 4.89892761076
# Pressure Head in Pipe 1 is:  4.9009718867 m bottom head is: 5.05668341777
# Pressure Head in Pipe 2 is:  3.72589608878 m bottom head is: 3.834204424
# v in Pipe 1 is:  0.168425685789 m/s
# v in Pipe 2 is:  3.73787229103 m/s
# Total Head in Pipe 0 is:  4.94745643758 m
# Total Head in Pipe 1 is:  4.90241771808 m
# Total Head in Pipe 2 is:  4.43801073016 m
# K0-1 = 0.220914919144
# K0-2 = 2.49883119488
# Branch flow ratio = 0.915778711301
# Re = 526315.789474
# The total time is  381.04242897  s
# 0

# %%
oris = np.arange(0.01, 0.11, 0.01)
for ori in oris:
    Atao = p1.AofH(0.83*ori,True)
    Q = 0.3**2*np.pi/4.*1.
    H = (Q/0.78/Atao)**2/2/9.81+0.83*ori
    print ori, H
